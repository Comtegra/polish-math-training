# %%
import numpy as np
import random
import torch
def set_random_seed(seed: int = 42):
    """
    Set the random seed for reproducibility across Python, NumPy, and PyTorch.

    Parameters:
        seed (int): The seed value to use.
    """
    # Set the seed for Python's built-in random module
    random.seed(seed)

    # Set the seed for NumPy
    np.random.seed(seed)

    # Set the seed for PyTorch
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    # Ensure deterministic behavior in cuDNN (may impact performance)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_random_seed(42)

import os
os.environ["WANDB_API_KEY"] = "YOUR KEY GOES HERE"
os.environ["WANDB_PROJECT"] = "GRPO-Qwen-0.5-Instruct"

# !wandb login
# !pip install flash-attn
# !pip install trl

import os
import hashlib
import tarfile
import requests
import re
import wandb
from torch.nn.utils.rnn import pad_sequence
from datasets import load_dataset, Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, Trainer, TrainingArguments, DataCollatorForLanguageModeling, TrainerCallback, PreTrainedTokenizerBase
from trl import GRPOConfig, GRPOTrainer

# %%
SYSTEM_PROMPT = """
Respond in the following format:

<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

def extract_answer_from_model_output(text):
    """
    Extracts the value from the last <answer> tag in the text.
    Returns None if no valid answer is found.
    """
    # Split on <answer> and take everything after the last occurrence
    parts = text.split("<answer>")
    if len(parts) < 2:  # No <answer> tag found
        return None

    last_part = parts[-1]

    # Extract content up to </answer>
    if "</answer>" not in last_part:
        return None

    answer = last_part.split("</answer>")[0].strip()
    return None if answer == "..." else answer

def extract_answer_from_dataset(text):
    """
    Extracts the answer from the dataset.
    The dataset separates the answer using the '####' delimiter.
    """
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# %%
def prepare_dataset(split="train"):
    """Load and prepare your local dataset from the 'dataset-polish-math' folder."""
    
    data_files = {
        "train": "dataset-polish-math/train.jsonl",
        "test": "dataset-polish-math/test.jsonl"
    }

    data = load_dataset("json", data_files=data_files, split=split)
    formatted_data = []

    for example in data:
        formatted_example = {
            "prompt": [
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": example["question"]}
            ],
            "answer": extract_answer_from_dataset(example["answer"])
        }
        formatted_data.append(formatted_example)

    return formatted_data

def build_prompt(messages):
    """
    Build a single prompt string from a list of messages.
    Each message is expected to be a dictionary with 'role' and 'content' keys.
    This function concatenates all message contents, preserving the training format.
    """
    return "\n".join([msg["content"].strip() for msg in messages])

class ChatDataCollator:
    def __init__(self, tokenizer: PreTrainedTokenizerBase, max_length: int = 512):
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __call__(self, batch):
        inputs = []
        labels = []
        for example in batch:
            # Here we assume the last message is the target (assistant's output)
            prompt = build_prompt(example["messages"][:-1])
            target = example["messages"][-1]["content"]

            # Concatenate prompt and target (add a newline between them)
            full_text = prompt + "\n" + target
            tokenized = self.tokenizer(full_text, truncation=True, max_length=self.max_length)
            input_ids = torch.tensor(tokenized["input_ids"])
            inputs.append(input_ids)
            # You can choose to set labels equal to input_ids, or modify as needed.
            labels.append(input_ids)

        inputs_padded = pad_sequence(inputs, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        labels_padded = pad_sequence(labels, batch_first=True, padding_value=-100)
        return {"input_ids": inputs_padded, "labels": labels_padded}

# %%
def extract_cot_archive_local(local_archive_path, extract_path):
    """
    Extracts the CoT archive from a local file.

    Parameters:
        local_archive_path (str): The path to the locally stored tar.gz archive.
        extract_path (str): Directory where the archive should be extracted.
    
    Returns:
        str: The path to the extracted directory containing CoT files.
    """
    if not os.path.exists(extract_path):
        os.makedirs(extract_path, exist_ok=True)
    extract_dir = os.path.join(extract_path, "cot_files")
    if not os.path.exists(extract_dir):
        print("Extracting CoT archive from local file...")
        with tarfile.open(local_archive_path, "r:gz") as tar:
            tar.extractall(path=extract_dir)
    return extract_dir

def prepare_sft_dataset(num_examples=500):
    """
    Prepare SFT examples in the chat format required by your custom collator.
    Each example will be a dict with a "messages" key.
    """
    SYSTEM_PROMPT = """
    Respond in the following format:
    <reasoning>
    ...
    </reasoning>
    <answer>
    ...
    </answer>
    """

    local_archive_path = "cot.tar.gz"  # <-- update this path accordingly
    extract_dir = extract_cot_archive_local(local_archive_path, extract_path="cot_archive")
    
    data = load_dataset(
        "json", 
        data_files={"train": "dataset-polish-math/train.jsonl"}, 
        split="train"
    )
    sft_examples = []
    for example in data:
        question = example["question"].strip()
        # Compute the filename based on the SHA-256 hash of the question.
        filename = hashlib.sha256(question.encode()).hexdigest() + ".txt"
        file_path = os.path.join(extract_dir, filename)
        if os.path.exists(file_path):
            with open(file_path, "r", encoding="utf-8") as f:
                cot_output = f.read().strip()
            # Build the chat-format example.
            formatted_example = {
                "messages": [
                    {"role": "system", "content": SYSTEM_PROMPT},
                    {"role": "user", "content": question},
                    {"role": "assistant", "content": cot_output}
                ]
            }
            sft_examples.append(formatted_example)
        if len(sft_examples) >= num_examples:
            break
    if len(sft_examples) < num_examples:
        print(f"Warning: Only found {len(sft_examples)} SFT examples.")
    else:
        print(f"Prepared {len(sft_examples)} SFT examples.")
    return sft_examples

# %%
def _extract_last_number(text):
    """
    Extracts the last number from text if it's properly separated.
    The number must be at the end and separated by space or = sign.
    Ignores $ and % signs.
    Returns None if no valid number is found.
    """
    import re

    # Remove $ and % signs
    text = text.replace('$', '').replace('%', '')

    # Look for numbers that are:
    # - preceded by space or = or start of string (via \b or ^)
    # - followed by end of string or space
    pattern = r'(?:^|\s|=)\s*(-?\d*\.?\d+)\s*$'
    match = re.search(pattern, text)
    return float(match.group(1)) if match else None

def _extract_single_number(text):
    """
    Extracts a single number from text if exactly one exists,
    otherwise returns None.
    """
    import re
    numbers = re.findall(r'-?\d*\.?\d+', text)
    return float(numbers[0]) if len(numbers) == 1 else None

def evaluate_model(model, tokenizer, eval_examples, device):
    """Evaluates the model on a set of examples and prints detailed results."""
    model.eval()
    correct = 0
    total = len(eval_examples)
    print("\n" + "="*50)
    print("EVALUATION ON", total, "EXAMPLES")
    print("="*50)
    for example in eval_examples:
        # Build the full prompt using the same method as training.
        full_prompt = build_prompt(example["prompt"])
        expected = example["answer"]
        # Tokenize the full prompt and generate a response from the model.
        inputs = tokenizer.encode(full_prompt, return_tensors="pt").to(device)
        outputs = model.generate(
            inputs,
            max_length=512,
            temperature=0.7,
            num_return_sequences=1
        )
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        # Extract the predicted answer from the model output.
        try:
            predicted = extract_answer_from_model_output(response)
            # Check correctness in multiple ways
            if predicted == expected:  # First try exact match
                is_correct = True
            else:
                # Try single number
                pred_num = _extract_single_number(str(predicted))
                exp_num = _extract_single_number(str(expected))
                if pred_num is not None and exp_num is not None and pred_num == exp_num:
                    is_correct = True
                else:
                    # Try last number
                    pred_num = _extract_last_number(str(predicted))
                    exp_num = _extract_last_number(str(expected))
                    is_correct = (pred_num is not None and exp_num is not None and
                                pred_num == exp_num)

            if is_correct:
                correct += 1
            # Print details of the evaluation.
            print("\nPrompt:")
            print(full_prompt)
            print("\nExpected Answer:")
            print(expected)
            print("\nExtracted Answer:")
            print(predicted)
            print("\nFull Generated Response:")
            print(response)
            print("\nCorrect:", "✓" if is_correct else "✗")
            print("-"*50)
        except Exception as e:
            print("\nFailed to parse model output for prompt:")
            print(full_prompt)
            print("Error:", e)
            print("-"*50)
    accuracy = (correct / total) * 100
    print(f"\nAccuracy: {accuracy:.2f}% ({correct}/{total})")
    print("="*50)
    model.train()
    return accuracy

# Define a custom callback class for evaluation.
class EvalCallback(TrainerCallback):
    def __init__(self, model, tokenizer, eval_examples, device):
        self.model = model
        self.tokenizer = tokenizer
        self.eval_examples = eval_examples
        self.device = device

    def on_train_begin(self, args, state, control, **kwargs):
        return control

    def on_epoch_begin(self, args, state, control, **kwargs):
        return control

    def on_step_end(self, args, state, control, **kwargs):
        if state.global_step % args.eval_steps == 0:
            print(f"\nEvaluating at step {state.global_step}:")
            evaluate_model(self.model, self.tokenizer, self.eval_examples, self.device)
        return control

    def on_epoch_end(self, args, state, control, **kwargs):
        return control

    def on_train_end(self, args, state, control, **kwargs):
        return control

# %%
def correctness_reward(prompts, completions, answer, **kwargs):
    """
    Assigns a reward based on the correctness of the model's answer.
    Also logs detailed metrics about the response.
    """

    responses = [completion[0]['content'] for completion in completions]
    extracted = [extract_answer_from_model_output(r) for r in responses]

    rewards = []
    for r, a in zip(extracted, answer):
        if r == a:  # Exact match case
            rewards.append(2.0)
        else:
            # Try numeric equivalence
            r_num = _extract_single_number(str(r))
            a_num = _extract_single_number(str(a))
            if r_num is not None and a_num is not None and r_num == a_num:
                rewards.append(1.5)
            else:
                rewards.append(0.0)

    # Log completion lengths
    completion_lengths = [len(response.split()) for response in responses]
    return rewards

def format_reward(completions, **kwargs):
    """
    Assigns a reward for adhering to the desired XML format.
    Also logs detailed format compliance metrics.
    """
    responses = [completion[0]['content'] for completion in completions]
    rewards = []
    format_scores = []

    for response in responses:
        score = 0.0
        if "<reasoning>" in response: score += 0.20
        if "</reasoning>" in response: score += 0.20
        if "<answer>" in response: score += 0.20
        if "</answer>" in response: score += 0.20
        rewards.append(score)
        format_scores.append(score)

    return rewards

# %%
# TEST
import json
from datasets import load_dataset

data = load_dataset("json", data_files="dataset-polish-math/train.jsonl", split="train")
for idx, example in enumerate(data):
    print(f"Example {idx} type: {type(example)}")
    print(f"Example {idx} content: {example}")
    if idx >= 2:
        break
# Out:
# Example 0 type: <class 'dict'>
# Example 0 content: {'question': 'Adam kupił 20 jabłek, a potem oddał 5 swoim przyjaciołom. Następnie kupił jeszcze 8 jabłek. Ile jabłek ma teraz Adam?', 'answer': 'Najpierw odejmujemy oddane jabłka: 20 - 5 = <<20-5=15>>15.\nNastępnie dodajemy kupione jabłka: 15 + 8 = <<15+8=23>>23.\n#### 23'}
# Example 1 type: <class 'dict'>
# Example 1 content: {'question': 'Basia ma 24 cukierki. Najpierw oddała 4 cukierki swojej siostrze, a następnie podzieliła resztę równo między 4 koleżanki. Ile cukierków dostała każda koleżanka?', 'answer': 'Najpierw obliczamy resztę cukierków: 24 - 4 = <<24-4=20>>20.\nNastępnie dzielimy je między 4 koleżanki: 20 / 4 = <<20/4=5>>5.\n#### 5'}
# Example 2 type: <class 'dict'>
# Example 2 content: {'question': 'Janek miał 50 zł. Kupił książkę za 18 zł, a potem zeszyt za 7 zł. Ile pieniędzy mu pozostało?', 'answer': 'Najpierw odejmujemy koszt książki: 50 - 18 = <<50-18=32>>32.\nNastępnie odejmujemy koszt zeszytu: 32 - 7 = <<32-7=25>>25.\n#### 25'}

# %%
def main():
    # Determine the device: use GPU if available, else fallback to CPU.
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Model configuration.
    model_name = "Qwen/Qwen2.5-0.5B-Instruct"
    output_dir = "math_solver_model"

    # Load the pre-trained model on CPU first, then move to GPU.
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        torch_dtype=torch.bfloat16,
        attn_implementation="sdpa",
        device_map="auto"
    )
    model = model.to(device)

    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tokenizer.pad_token = tokenizer.eos_token

    examples_to_use_for_evaluation = 30

    ##############################
    # Step 0. PRE-SFT EVALUATION #
    ##############################

    # Immediately after loading the model, tokenizer, and determining the device (i.e. in main(), after model/tokenizer load)
    # Insert this code block to prepare evaluation examples and run evaluation BEFORE SFT fine-tuning.
    all_data = prepare_dataset("train")
    random.shuffle(all_data)
    eval_data = all_data[:examples_to_use_for_evaluation]

    print("\nInitial model evaluation BEFORE SFT:")
    pre_sft_accuracy = evaluate_model(model, tokenizer, eval_data, device)
    print(f"Pre-SFT Accuracy: {pre_sft_accuracy:.2f}%")

    ###########################
    # Step 1: SFT Fine-Tuning #
    ###########################
    print("\nPreparing SFT dataset...")
    sft_dataset = prepare_sft_dataset(num_examples=500)

    sft_training_args = TrainingArguments(
        output_dir="sft_output",
        overwrite_output_dir=True,
        num_train_epochs=1,
        per_device_train_batch_size=2,
        learning_rate=5e-5,
        save_steps=100,
        bf16=True,
        gradient_checkpointing=True,
        remove_unused_columns=False,
        report_to=[]
    )

    print("\nStarting SFT fine-tuning...")
    sft_trainer = Trainer(
        model=model,
        args=sft_training_args,
        train_dataset=sft_dataset,
        data_collator=ChatDataCollator(tokenizer)
    )
    sft_trainer.train()

    # Evaluate the model after SFT
    post_sft_accuracy = evaluate_model(model, tokenizer, eval_data, device)
    print(f"\nPost-SFT Accuracy: {post_sft_accuracy:.2f}%")
    print(f"\nImprovement after SFT: {post_sft_accuracy - pre_sft_accuracy:.2f}%")

    ##########################
    # Step 2: RL Fine-Tuning #
    ##########################
    # Prepare RL dataset (using the same prepare_dataset function).
    all_data = prepare_dataset("train")
    random.shuffle(all_data)

    train_data = all_data[examples_to_use_for_evaluation:]

    # Define training configuration using GRPOConfig.
    training_args = GRPOConfig(
        output_dir=output_dir,
        learning_rate=5e-6,
        logging_steps=5,
        eval_steps=50,
        bf16=True,
        per_device_train_batch_size=8,
        gradient_accumulation_steps=4,
        max_steps=500,
        num_train_epochs=1,
        save_steps=100,
        max_grad_norm=0.1,
        num_generations=8,
        max_completion_length=300,
        report_to=["wandb"]
    )

    wandb.init(
        config={
            "model_name": model_name,
            "learning_rate": training_args.learning_rate,
            "batch_size": training_args.per_device_train_batch_size,
            "num_epochs": training_args.num_train_epochs
        }
    )

    # Create the trainer with our reward functions.
    trainer = GRPOTrainer(
        model=model,
        processing_class=tokenizer,
        reward_funcs=[format_reward, correctness_reward],
        args=training_args,
        train_dataset=train_data,
    )

    trainer.add_callback(EvalCallback(model, tokenizer, eval_data, device))

    # Start training
    trainer.train()

    print("\nFinal model evaluation AFTER GRPO:")
    post_grpo_accuracy = evaluate_model(model, tokenizer, eval_data, device)
    print(f"Post-GRPO Accuracy: {post_grpo_accuracy:.2f}%")
    print(f"Improvement after GRPO: {post_grpo_accuracy - pre_sft_accuracy:.2f}%")

    ###########################
    # Step 3. SAVE THE MODEL       #
    ###########################

    print("Saving GRPO fine-tuned model to 'grpo_finetuned_model'...")
    model.save_pretrained("grpo_finetuned_model")
    # Save the tokenizer:
    tokenizer.save_pretrained("grpo_finetuned_model")

    # Close wandb
    wandb.finish()


if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Initial model evaluation BEFORE SFT:
#
# ==================================================
# EVALUATION ON 30 EXAMPLES
# ==================================================
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Zosia miała 75 cukierków. Podzieliła je równo między 5 przyjaciół, a sama zatrzymała 5 cukierków. Ile cukierków otrzymał każdy przyjaciel?
#
# Expected Answer:
# 14
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Zosia miała 75 cukierków. Podzieliła je równo między 5 przyjaciół, a sama zatrzymała 5 cukierków. Ile cukierków otrzymał każdy przyjaciel? Wzór to: X = C / 5, gdzie X to amount of candies, C to total number of candies.
#
# Podsumowując, zatem каждi przyjaciół otrzymał X cukierków. Jakiekolwiek informacje nie potrzebuję, więc powyższy wzór jest poprawny dla tego zadania. Zobaczmy, jak działa:
#
# 1) Podzieliłem 75 cukierków na 5 przyjaciół, co zakończy się, że każda przyjaciela otrzymuje 15 cukierków (75/5=15).
# 2) Oto przykład: 1. Zosia otrzymał 15 cukierków.
# 2. Kobieta 2 otrzymał 10 cukierków.
# 3. Kobieta 3 otrzymał 6 cukierków.
# 4. Kobieta 4 otrzymał 3 cukierki.
# 5. Kobieta 5 otrzymał 1 cukierek.
#
# Jednakże, jeśli masz więcej lub razem więcej danych, możesz wykorzystać ten wzór, aby obliczyć liczbę cukierków, które otrzyma każdy przyjaciel, ale nie możesz dostarczyć szczegółowych informacji o tym, ile jest candy w każdej przyjacie.
#
# Oto przykład, gdy masz 90 cukierków:
#
# 1) 90 / 5 = 18, więc każda przyjaciela otrzymuje 18 cukierków.
#
# Wszystkie odpowiedzi są podsumowane w jednej linii, więc możemy przypisać "Oto przykład" do tej listy, która zawiera tylko one, takie jak wynik i sposób, przez który ten wynik został zapisany. To jest prawdziwy sposób na tworzenie listy z powyższego typu, ale nie jest to kluczowe. Wyjaśnienie może być dalsze, jeśli chcesz, ale jest to poprawna metodą,
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Urszula kupiła 4 zeszyty po 7 zł. Ile zapłaciła?
#
# Expected Answer:
# 28
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Urszula kupiła 4 zeszyty po 7 zł. Ile zapłaciła? Wybierz odpowiedź.
#
# A) 21
# B) 35
# C) 49
# D) 68
#
# Oto konkretna odpowiedź:
#
# Rozwiązanie:
# 4 zeszyty * 7 zł = 28 zł
# Odpowiedź: C) 49
#
# Przypomnij, że liczba jest równa podstawieniu liczby na przedział. Zatem 4 zeszyty wynoszą 28 zł, a 28 zł otrzymujemy po 7 zł, co wynosi 49 zł.
#
# Zobaczmy, jak to wytwarzyć z programu Python:
# ```python
# zeszpyta = 4
# peselka = 7
# suma = zeszpyta * peselka
# print(suma)
# ```
# W tym przykładzie wygenerowaliśmy 4 zeszyty i obliczyliśmy ile zapłacili po 7 zł. Wynik to 49 zł, więc odpowiedź C) 49 jest prawidłowa.
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Monika kupiła 4 pudełka kredek, w każdym po 15 kredek. Po użyciu 10 kredek, ile kredek pozostało?
#
# Expected Answer:
# 50
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Monika kupiła 4 pudełka kredek, w każdym po 15 kredek. Po użyciu 10 kredek, ile kredek pozostało? To zadanie matematyczne, które rozwiązać można zgodnie z podanymi warunkami. Aby uzyskać wynik, potrzebujemy pomocy:
#
# 1) Rozwiąż równanie: 4 pudełka kredek - 10 kredek = ile kredek
#
# 2) Wyznacz liczbę pudełka kredek, która zostało użyta.
#
# 3) Zwróć uwagę na warunek: po użyciu 10 kredek, ile kredek pozostało to nie może być większe niż 4.
#
# 4) Uwzględni wartość 10 do obliczenia licznika.
#
# Rozwiązanie:
# 1) 4 - 10 = -6 (ale to nie jest prawidłowy, ponieważ nie można używać negative kredek)
#
# 2) Podejmuj 10 kredek od 4 pudełka: 4 - 10 = -6 (nie jest to prawidłowo)
#
# 3) Liczba pudełka kredek, którą ma użyć: 4 + 10 = 14
#
# 4) Wynikiem jest 14 kredek, więc ile kredek pozostało będzie to 14.
#
# Aby uzyskać odpowiedź na ten zadanie, musisz przeprowadzić dodatkowe wykonywanie, co może wymagać kilku sekund. Oto poprawy rozwiązania:
#
# Rozwiąż równanie: 4 pudełka - 10 kredek = ile kredek
#        4 - 10 = ile kredek
#        -6 = ile kredek
#
# Wynikiem jest 14 kredek, więc ile kredek pozostało będzie to 14.
#
# Aby uzyskać odpowiedź na ten zadanie, musisz przeprowadzić dodatkowe wykonywanie, co może wymagać kilku sekund. Oto poprawy rozwiązania:
#
# Rozwiąż równanie: 4 pudełka - 10 kredek =
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W sklepie komputerowym sprzedano 12 myszek po 45 zł każda. Jaki był łączny przychód?
#
# Expected Answer:
# 540
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W sklepie komputerowym sprzedano 12 myszek po 45 zł każda. Jaki był łączny przychód?
# Rozwiązanie:
# Przez dzielenie liczby przez liczbę naturalną, wynosić wartość całkowitą.
#
# 12 myszków po 45 zł = 12 * 45 = 540 zł
# Jaka jest wartość tej sumy?
# Rozwiązanie:
# Przez dodawanie liczby do liczby, wynosić wartość całkowita.
#
# 540 zł + 45 zł = 585 zł
# Jaka jest to suma?
# Aby otrzymać tę sumę, potrzebujesz 12 myszków i 45 zł.
# Czyli 12 myszków po 45 zł = 585 zł.
#
# Polecam również sprawdzić konkretny wyrażenie na język polskim lub angielskim, aby uzyskać bardziej szczegółowy i dokładny wynik. Zamiast tego możesz użyć funkcji Pythona, gdzie łatwo będzie być łatwe przetworzenie tego równania w języku zapisanej w kodzie.
#
# Zrozumienie: Dla niego wymagany jest 12 myszków i 45 zł, więc suma wynosi 585 zł. Jakiego wyniku ma to suma? Aby znaleźć jej wartość, musisz podzielić 585 zł przez 12 myszków (czyli 45 zł) oraz dodac 45 zł (jakieś więcej).
#
# Należy pamiętać, że nie jestem w stanie pomóc w rozmowie lub kontekście. Jeśli masz pytanie więcej, proszę opisując, co chcesz, odpowiem za pomocą odpowiednich metod. Wszystkie informacje są przechowywane w celu zapewnienia prawidłowości i dokładności odpowiedzi. Niech się spodziewam, jeśli masz jakieś inne pytania lub informacje, które potrzebują wyjaśnienia. Warto też upewnić się, że jesteś pewien o tym, co ro
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Uczestnik maratonu przebiegł 42 km. Jeśli przez pierwsze 10 km biegł w tempie 6 min/km, a przez resztę w tempie 5 min/km, ile czasu spędził na biegu?
#
# Expected Answer:
# 220
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Uczestnik maratonu przebiegł 42 km. Jeśli przez pierwsze 10 km biegł w tempie 6 min/km, a przez resztę w tempie 5 min/km, ile czasu spędził na biegu? Oto odpowiedź:
#
# 7 min
#
# Oto przepis działania:
#
# 1. Biegł pierwszy 10 km w tempie 6 min/km.
#    - Wartość: 10 * 6 = 60 min
# 2. Biegł drugi 32 km w tempie 5 min/km.
#    - Wartość: 32 * 5 = 160 min
#
# Total czasu: 60 + 160 = 220 min
#
# Zatem czas, odgrywany na biegu, wynosi 220 min.
#
# Aby uzyskać dokładną wartość, powinna być większa niż 180 min (np. 200 min), ale nie jest to prawidłowym rozszerzeniem tego wyniku.
#
# To zrozumiałe?
#
# Pamiętajmy, że czas biegający w tempie nie jest określony w formatie "min/min", ale "k/min". Zatem 6 min lub 5 min to jednakowe wartości dla tych dwóch różnych typów czasów biegania.
#
# Wszystko to sprawia, że obliczenie nie jest jednym z czynników, które można skupić na konkretny sposób, aby uzyskać dokładny wynik. To zależy od kontekstu i potrzebnych szczegółów. W takim przypadku, może być dobrze poprosić o dodatkowe informacje lub opisu, aby uzyskać dokładne wyniki.
#
# Niestety, nie mogę dostarczyć dokładnego wyniku po porozumieniu, ponieważ nie ma podobnej liczby czasu w formacie "min/min" do porównania. Aby uzyskać dokładną odpowiedź, musisz znamieć konkretną liczbę czasu biegania.
#
# Niech chętnie pomogę ci, gdy będzie się przyjedzie więcej
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Marcin kupił 4 pudełka ołówków, w każdym po 12 ołówków. Zgubił 3 ołówki. Ile ołówków pozostało?
#
# Expected Answer:
# 45
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Marcin kupił 4 pudełka ołówków, w każdym po 12 ołówków. Zgubił 3 ołówki. Ile ołówków pozostało? W tym przypadku, zawsze będziesz miał 1 ołówek w razie konkretnego problemu, więc jeśli masz więcej niż 12 ołówków, to ma być 0 ołówków. Aby uzyskać dokładną ilość, musisz sprawdzić kilka warunków.
#
# Rozumiem, że Cię nie pomagało, ale jeśli masz jakieś podobne pytania, mogę ci pomóc jeszcze dalej! 😊
#
# Pamiętaj: Aby uzyskać dokładny wynik, musisz sprawdzić kilka warunków i zastosować odpowiednie warunki. Jeśli masz więcej niż 12 ołówków, możesz jednak mieć 0, ponieważ na pewno nie ma żadnych konkretnych ograniczeń. Dlatego musisz sprawdzić kilka warunków i zastosować odpowiednie warunki, aby uzyskać dokładny wynik. Jeśli masz więcej niż 12 ołówków, możesz jednak mieć 0, ponieważ na pewno nie ma żadnych konkretnych ograniczeń. Dlatego musisz sprawdzić kilka warunków i zastosować odpowiednie warunki, aby uzyskać dokładny wynik. Jeśli masz więcej niż 12 ołówków, możesz jednak mieć 0, ponieważ na pewno nie ma żadnych konkretnych ograniczeń. Dlatego musisz sprawdzić kilka warunków i zastosować odpowiednie warunki, aby uzyskać dokładny wynik. Jeśli masz więcej niż 12 ołówków, możesz jednak mieć 0, ponieważ na pewno nie ma żadnych konkretnych ograniczeń. Dlatego musisz sprawdzić kilka warunków i zastosować odpowiednie warunki, aby uzyskać dokładny wynik. Jeśli masz więcej niż 12 ołówków, możesz jednak mieć 0, ponieważ na pewno nie ma żadnych konkretnych ograniczeń. D
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Adam kupił 20 jabłek, a potem oddał 5 swoim przyjaciołom. Następnie kupił jeszcze 8 jabłek. Ile jabłek ma teraz Adam?
#
# Expected Answer:
# 23
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Adam kupił 20 jabłek, a potem oddał 5 swoim przyjaciołom. Następnie kupił jeszcze 8 jabłek. Ile jabłek ma teraz Adam?
#
# 1) Wzór: A + B = C
#    gdzie A to liczba jabłek, które oddali Adam, B to liczba jabłek, które oddali przyjaciół i C to liczba jabłek, które oddali Adam.
#
# 2) Wyznaczenie:
#    - Adam oddał 5 przyjaciół, więc A = 5.
#    - Adam oddał 8 jabłek, więc C = 8.
#
# 3) Podstawienie w równanie:
#    A + B = C => 5 + B = 8
#
# 4) Rozwiązanie:
#    B = 8 - 5 = 3
#
# 5) Wynik:
#    Poniżej znajduje się ilość jabłek, które ma Adam po raz drugi: 5 + 3 = 8
#
# 6) Odpowiedź:
#    Adam ma 8 jabłek.
#
# Oto odpowiedź na pytanie: "Ile jabłek ma teraz Adam?"
# Aby zauważyć, że obiekt jest niepotrzebny, musimy skorzystać z podstawowego wzoru: A + B = C, gdzie A to liczba jabłek, które oddali Adam, B to liczba jabłek, które oddali przyjaciół i C to liczba jabłek, które oddali Adam. W tym przypadku A = 5 (jabłka odzielał przyjaciół), B = 3 (jabłka odzielał Adam) i C = 8 (jabłka odzielał przyjaciół). Wyznaczając A + B, obliczymy, ile jabłek ma Adam po raz drugi: 5 + 3 = 8. Odpowiedź: Adam ma 8 jabłek.
#
# Wzór: A + B = C
#    gdzie A to liczba jabłek, które oddali Adam, B to liczba jabłek, które oddali przyjaciół i C to licz
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olek zebrał 84 liści, podzielił je na 7 równych stosów. Ile liści w każdym stosie?
#
# Expected Answer:
# 12
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olek zebrał 84 liści, podzielił je na 7 równych stosów. Ile liści w każdym stosie?
#
# 1) 12 liści w pierwszym stosie
# 2) 16 liści w drugim stosie
# 3) 18 liści w trzecim stosie
# 4) 20 liści w czwartego stosie
# 5) 24 liści w piątkiego stosie
#
# Rozwiązanie:
# Znajdź dzielnik liczby 84 przez 7, aby mieć istniejące 7 równych stosów. W przypadku tego, że nie jest to możliwe, rozumiem, że zazwyczaj nie można dodać więcej liczb do siebie. W takim razie zamiast zasady podzielania 84 na 7 musi być rozmiar ostatniego stosu większy od 0 i mniejszy niż 7.
#
# Przykro mi, ale nie mogę uzyskać dokładnej odpowiedzi na ten zadanie. Oto przykładowy sposób rozwiązania tego problemu:
#
# 84 ÷ 7 = 12
# Warto zauważyć, że 12 - 1 = 11, co jest większe niż 0 i mniejsze niż 7.
# Dlatego rozmiar ostatniego stosu wynosi 11.
#
# Aby zapobiec, możesz skorzystać z potencjalnych dzielenia 84 przez 7 w różnorodnym rozkładzie, czyli:
#
# 84 = 9 × 9 + 3 × 7
# Tak więc rozmiar ostatniego stosu wynosi 9.
#
# Pamiętaj jednak, że w tym przypadku nie może być dodawany więcej liczb do siebie, ponieważ nie ma ani 9, ani 3 w sobie. To nie jest możliwe, więc rozwiązałem to po prostym sposobie. Aby uzyskać dokładną odpowiedź, potrzebuję więcej informacji lub podsumowując, jak się robi. Jeśli masz kilka informacji, proszę o informacje inną. Jeśli masz pewne warunki dotyczące rozd
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W restauracji przygotowano 85 dań, a 15 dań nie sprzedano. Ile dań sprzedano?
#
# Expected Answer:
# 70
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W restauracji przygotowano 85 dań, a 15 dań nie sprzedano. Ile dań sprzedano? To 60.
#
# Przepraszam za nieporozumienie, ale potrzebuję więcej informacji na temat rozpoznawania domu i zasobów. Możemy poruszyć to jeszcze raz w tym celu.
#
# Zapraszamy do kolejnych próbek! Jeśli chcesz poprawić czy niepoprawić czynniki, proszę podzielić się, jak mogę Ci pomóc! Zrozumiałeś, że jestem w stanie rozwijać bardziej szczegółowe informacje, jeśli chcesz? Wszystkie dany są zgodne z prawidłami i wymaganiem. Daj mi pewny, co jest potrzebne dla tej zadanej sprawie. Zrozumiałeś, że jestem w stanie rozwijać bardziej szczegółowe informacje, jeśli chcesz? Wszystkie dany są zgodne z prawidłami i wymaganiem. Daj mi pewnego, co jest potrzebne dla tej zadanej sprawie. Zrozumiałeś, że jestem w stanie rozwierać bardziej szczegółowe informacje, jeśli chcesz? Wszystkie dany są zgodne z prawidłami i wymaganiem. Daj mi pewnego, co jest potrzebne dla tej zadanej sprawie. Zrozumiałeś, że jestem w stanie rozwijać bardziej szczegółowe informacje, jeśli chcesz? Wszystkie dany są zgodne z prawidłami i wymaganiem. Daj mi pewnego, co jest potrzebne dla tej zadanej sprawie. Zrozumiałeś, że jestem w stanie rozwierać bardziej szczegółowe informacje, jeśli chcesz? Wszystkie dany są zgodne z prawidłami i wymaganiem. Daj mi pewnego, co jest potrzebne dla tej zadanej sprawie. Zrozumiałeś, że jestem w stanie rozwierać bardziej szczegółowe informacje
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Bartek kupił 2 paczki soków, w każdej 3 litry. Wypił 2 litry. Ile litrów soku zostało?
#
# Expected Answer:
# 4
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Bartek kupił 2 paczki soków, w każdej 3 litry. Wypił 2 litry. Ile litrów soku zostało?
#
# Rozwiązanie:
# 1. Rozwiąż liczbę litrów soku: 2 * 3 = 6
# 2. Wypięli 2 litery, więc pozostały 6 - 2 = 4 litry
#
# Oto rozwiązania:
#
# 1. Wczytujemy zapisy na komputerze.
# 2. Rozważmy, jak działa obliczenie:
#    - Pierwszy argument (wartość): 2
#    - Drugi argument (operacja): 2 * 3 = 6
#    - Trzeci argument (wynik): 6
#
# Wydajemy wynik: 6 litry
#
# 3. Wypięliśmy 2 litery, więc pozostała 6 - 2 = 4 litry
#
# Dziękuję za pomocy! Jeśli chcesz morenić lub rozwiązać inne zadania, proszę podać.
#
# Każdy raz, gdy będziesz mi potrzebował, mogę Ci przekazać odpowiedź i dodac więcej informacji. Czy masz jeszcze jakieś pytania?
#
# Pamiętaj, aby nie odbędzieć się niespodzianek, jeśli to nie jest wymagane. Zawsze mogę Ci pomóc, nawet jeśli to nie jest najbardziej efektualny sposób. Dajem Ci tylko dobre zdania i oto już jest moja odpowiedź.
#
# Jeśli chcesz morenić lub rozwiązać inną zadanie, proszę podać. Jeśli masz jeszcze jakieś pytania, zawsze mogę Ci pomóc. Abyś mógł skorzystać z pełnej odpowiedzi, zastanawiasz się, czy możesz dać dobre zdania?
#
# Za dużo czego Ci pomogę! Jeśli masz jeszcze jakieś pytania, zawsze mogę Ci pomóc. Abyś mógł skorzystać z pełnej odpowiedzi, zastanawiasz się, czy możesz dać dobre zdania?
#
# Oczywiście, zawsze mogę Ci pomóc. Abyś mógł skorzyst
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jacek kupił 3 opakowania markerów, w każdym po 8 markerów. Ile markerów kupił?
#
# Expected Answer:
# 24
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jacek kupił 3 opakowania markerów, w każdym po 8 markerów. Ile markerów kupił?
#
# Reasoning:
# To jest简单问题，只需要用除法来计算总数量。Jacek kupił 3 opakowania, a każdy opakowy ma 8 markerów. Zatem ilość markerów w jednym opakowaniu to 3 * 8 = 24. To jest suma wszystkich opakowanych markerów.
#
# Answer:
# 3 + (3 * 8) = 27 markerów.
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W pewnym ogrodzie posadzono 8 rzędów drzew, w każdym rzędzie 9 drzew. Jeśli 1/3 drzew ulegnie uszkodzeniu, ile drzew pozostanie zdrowych?
#
# Expected Answer:
# 48
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W pewnym ogrodzie posadzono 8 rzędów drzew, w każdym rzędzie 9 drzew. Jeśli 1/3 drzew ulegnie uszkodzeniu, ile drzew pozostanie zdrowych? Wartość wynikowej to: (8 * 9) / 3 = 24. Jeśli 1/3 drzew ulegnie uszkodzeniu, to 1/3 z 9 drzew ulegnie. To równa się 3. Oto ilość zdrowych drzew: 8 - 3 = 5.
#
# Oto komórki odpowiedzi:
#
# - Reasoning: Czyli 8 drzew po 1/3 jego liczby są 7 drzew. A jeśli 1/3 jest uległej do siebie, to jest trudno, ale wtedy zostaje 6 drzew. A gdy tylko 1 drzewu ulegnie, to jest 5 drzew.
# - Answer:
# 5 drzew.
#
# Oto poprawne odpowiedzi:
#
# - Reasoning: Czyli 8 drzew po 1/3 jego liczby są 7 drzew. A jeśli 1/3 jest uległej do siebie, to jest trudno, ale wtedy zostaje 6 drzew. A gdy tylko 1 drzewu ulegnie, to jest 5 drzew.
# - Answer:
# 5 drzew.
#
# Pamiętajmy, że na początku nie ma informacji o liczbach drzew, więc musimy wyrazać ich jako liczby całkowite. Podsumujmy, że 8 * 9 = 72 drzew. Ili 72 / 3 = 24 drzew. A jeśli 1/3 ulegnie do siebie, to 1/3 * 9 = 3 drzewi. Ili 8 - 3 = 5 drzew. A jeśli 1 drzewu ulegnie, to 1 drzewo. Oto poprawny obliczenie:
#
# - Reasoning: Czyli 8 drzew po 1/3 jego liczby są 7 drzew. A jeśli 1/3 jest uległ
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Halina upiekła 4 blachy ciastek po 20 ciastek, sprzedała 8 ciastek. Ile ciastek zostało?
#
# Expected Answer:
# 72
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Halina upiekła 4 blachy ciastek po 20 ciastek, sprzedała 8 ciastek. Ile ciastek zostało? Ciastka to 10% od ciasta, więc:
# 1. Ciastek - 4 * 10% = 4 * 0.1 = 0.4
# 2. Ciastek - 8 * 10% = 8 * 0.1 = 0.8
#
# Total: 0.4 + 0.8 = 1.2
#
# Odpowiedź: Ciastek to 1.2, czyli 12%. Ciastek na wszystkich 20 ciastkach były 12.
#
# Zazwyczaj w tej sytuacji wynika, że ciasta jest najwięcej, co znacza, że ciastki są najmniejsze. W takim przypadku Ciasta jest 97% i Ciastek 3%, a 97% * 8 = 77% Ciastek. Ciastek to 77/100 = 0.77 czyli 77%. Ciastek to 5.33% (o ile Ciasta jest 97%). Ciastek to 6% (o ile Ciasta jest 77%).
#
# Odpowiedź: Ciastek to 77% (czyli 77%), czyli 0.77 czyli 77%. Ciastek to 5.33% (czyli 5.33%), czyli 5.33%.
#
# Dziękuję za pomoc! Jeśli masz jakieś więcej pytania, nie starać się zauważyć, jak możesz je pomóc. Wybrać Cię najlepiej. Jeśli potrzebujesz informacji o drugich tematach, mogę ją podać. Czy jesteś zainteresowany bardziej szczegółowymi informacjami? Oto przykład:
# "Jakie jest wartość ciasta dla ciastek? Jeśli Ciasta ma 97%, a Ciastek 3%, to how many are left if there are only 8?"
#
# Jako sztuczna inteligencja, nie mogę dowiedzieć
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia zbiera na nowy telefon, który kosztuje 2400 zł. Udało jej się zaoszczędzić 30% tej kwoty. Ile jeszcze musi zaoszczędzić, aby kupić telefon?
#
# Expected Answer:
# 1680
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia zbiera na nowy telefon, który kosztuje 2400 zł. Udało jej się zaoszczędzić 30% tej kwoty. Ile jeszcze musi zaoszczędzić, aby kupić telefon? To jest równa się 70% kwoty, co wynosi 1680 zł.
# Reasoning: Kiedy masz 2400 zł, oznacza to 80% kwoty (2400/100 = 24). Kiedy masz 30% kwoty, oznacza to 2400/50 = 48 zł. Aby zrozumieć, jak ma być 70%, oznaczasz liczbę kwot, którą musisz zoszczędzić, czyli 1680 zł. Zrozumienie tego problemu jest ważnym dla wszystkich ludzi, którzy mają pewne sumy w banku i potrzebują zapewnienia, aby byłyby ich konto pełnowagi.
#
# Answer:
# To ma być 70% kwoty, oznacza to 1680 zł. Aby uzyskać 70% kwoty, musisz otrzymać 1680 zł. Wtedy musisz zoszczędzić 1680 zł.
#
# Użytkownik: Jak mogę pomóc?
# Kasia: Oto kilka sugerii:
#
# 1) Otwórz swoją bankę i sprawdź, czy ta cena nie jest najwięcej na terenie. Może to być kilka razy więcej niż 2400 zł.
#
# 2) Sprawdź, czy są jakieś dodatkowe lub koszty na telefon. Jeśli tak, sprawdź, czy można je odnaleźć.
#
# 3) Możesz zwiększyć cenę na telefon, jeśli masz kilka pieniędzy. Możesz też usunąć niektóre elementy z kosztu telefonu.
#
# 4) Jeśli masz do czynienia z krajami zawsze trudniejszymi, możesz przekazać kropkę do krajów, które są bardziej trudne do dostarczenia
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Waldemar kupił 5 paczek długopisów, w każdej po 3 długopisy. Ile długopisów kupił?
#
# Expected Answer:
# 15
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Waldemar kupił 5 paczek długopisów, w każdej po 3 długopisy. Ile długopisów kupił? Wartość jednego długopisu wynosi 10 zł. Jakie jest totalna suma kupowania?
#
# To rozwiązać te sprawy, musimy pomagać w programowaniu matematycznego. Znajdź odpowiednie równania lub nierówności i rozwiąż je.
#
# 1. Rozwiąż równanie: 5x = 21
#    - Sprawdzenie: 5 * 4 = 21, więc x = 4
#
# 2. Rozwiąż nierówność: 3x > 9
#    - Sprawdzenie: 3 * 3 = 9, więc x > 3
#
# 3. Oblicz suma kosztu jednego długopisu i 5 długopisów:
#    - Jedno długopis kosztuje 10 zł
#    - 5 długopisów kosztują 5 * 10 = 50 zł
#    - Suma to 10 + 50 = 60 zł
#
# Rozwiązanie: Kupienie za długopisy to 60 zł.
#
# Zatem, kupienie za długopisy na 5 długopisach wynosi 60 zł. Pamiętaj, że wartość jednego długopisu to 10 zł. Czy mógłbyś podać więcej szczegółów lub potencjalnych problemów, aby mogłyśmy dostosować rozwiązanie do jego potrzeb? W tym przypadku nie jestes potrzebne dodatkowe informacje. Jeśli masz jakieś inne pytania, proszę o informację. Dostępny jest również zrozumienie problemów związanych z wyrażeniami liczb oraz operacjami arytmetycznymi. Wszystkie informacje, które ma się podobne do tych, mogą być dostarczone jako pomoc. Zamiast tego, chciałbym zwrócić uwagę na fakt, że jeśli podałeś więcej informacji, możesz skontaktować się z innymi osobami lub grupą,
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia miała 100 balonów, 40 pękło. Ile balonów zostało?
#
# Expected Answer:
# 60
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia miała 100 balonów, 40 pękło. Ile balonów zostało? W tym przypadku, jeśli każdy z 50 pękł, to 20 balonów zostało. Aby przekazać wszystkich balonów, musimy dodać 100 + 40 - 20 = 120 balonów. Zatem w tym przypadku jest 120 balonów.
#
# Wszystkie te liczby mogą być wyrazone jako funkcje:
# - Równoważne: x+y
# - Diferencja: x-y
#
# Dane są taka samo jak wcześniej, więc możemy zapisać:
# - Pękło: x
# - Balony: y
#
# Poniżej znajduje się przykładowa program, który sprawdza czy wszystko dobrze się robi:
#
# ```python
# def check_balloons():
#     # Używam metody input() do podania danych
#     x = int(input("Podaj liczbę pękłych balonów: "))
#     y = int(input("Podaj liczbę balony: "))
#
#     # Sprawdzamy, czy wszystkie pękli i wszystkie balony zostały dostarczone
#     if x == 0 and y == 0:
#         print("Balony nie mogą być zero.")
#     elif x != 0 or y != 0:
#         print("Nie można znaleźć takiej liczby.")
#     else:
#         # Sprawdzamy, czy wszystkie pękli
#         if x > y:
#             print("Balin nie mogą być większej niż pękła.")
#         else:
#             # Sprawdzamy, czy wszystkie balony zostały dostarczone
#             if y < x * (x+1) // 2:
#                 print("Nie można dostarczyć wszystkich balonyów.")
#             else:
#                 print("Przekazano wszystkie balony.")
#
# check_balloons()
# ```
#
# Ten kod przechowuje wszystkie dane oprogramowania, a następnie wykonuje kilka testów, aby sprawdzić, że działa poprawnie. Możemy je zastosować na konkretnych przypadkach, aby obliczyć odpowiednią ilość balon
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Na targu sprzedano 100 kg ziemniaków po 2,90 zł za kilogram. Ile wyniósł przychód?
#
# Expected Answer:
# 290 zł
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Na targu sprzedano 100 kg ziemniaków po 2,90 zł za kilogram. Ile wyniósł przychód? Na podstawie tej informacji, wynik będzie podobny do następującego:
# (100 kg / 2,90 zł/kg) * 100 = 361,04 zł
# Toszniki powinien wykorzystać odpowiednią metodę:
# 1. Wyznaczenie ilości ziemniaków: 100 kg / 2,90 zł = 34,52 kg (w zależności od dokładności sytuacji)
# 2. Wyrażenie prędkości: 34,52 kg / 2,90 zł = 12,75 m/s (w zależności od dokładności sytuacji)
# 3. Podstawienie w prędkość i czas: 12,75 m/s * 1 min * 60 s = 815,00 m/min
# 4. Otwieranie prędkości w miarę godzinową: 815,00 m/min / 60 min = 13,58 m/s
# 5. Otwieranie prędkości w miarę godzinową: 13,58 m/s * 1000 cm/m = 13,580 km/h
#
# Przykład: W tym przypadku, wynik będzie podobny do takiego przepisu:
# (34,52 kg / 2,90 zł) * 12,75 m/s = 13,580 km/h
#
# Zatem wynik to 13,580 km/h.
#
# Oto ten sposób, jak można się skorzystać ze struktury i funkcji Pythona:
#
# ```python
# # Zmienna do użycia za kwadrat
# kwadrat = 2
#
# # Użyj metody round() do obliczenia liczby zawsze mniejszej niż kwadratu
# wybrana_wynik = round(kwadrat ** 0.5)
#
# print(wybrana_wyn
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Felicja upiekła 100 ciastek i rozdzieliła je równo na 10 talerzy. Ile ciastek trafiło na każdy talerz?
#
# Expected Answer:
# 10
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Felicja upiekła 100 ciastek i rozdzieliła je równo na 10 talerzy. Ile ciastek trafiło na każdy talerz?
#
# Rozwiązanie:
# Ciasta rozdziela się na kilka części, a każda część to jedno ciasto. Wtedy Ciasta jest rozdzielone na 10 talerzy, więc Ciasta trafiła na każdego talerza o ile w tym talerze jest ciasta.
#
# Ciąstki rozdzielono na 10 talerzy, więc Ciasta trafiła na każdy talerz o ile w nim jest ciasta.
#
# Odpowiedź: Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz 10 ciastek (czyli 10% ciastek). Ciasta trafiła na każdy talerz o ile w nim jest ciasta, czyli 10%. Ciasta trafiła na każdy talerz o ile w nim jest ciasta, czyli 10%.
#
# Zatem Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o ile w nim jest ciasta. Ciasta trafiła na każdy talerz o
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa kupiła 3 paczki mleka po 1 litr. Ile litrów mleka kupiła?
#
# Expected Answer:
# 3
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa kupiła 3 paczki mleka po 1 litr. Ile litrów mleka kupiła? To pytanie jest odpowiednie do rozwiązania podstawowej addickiej matematyki. Zatem obliczymy liczbę:
#
# 3 * 1 = 3
#
# Powyższa liczba to ilość mleka, które kupiła Ewa. Jakiekolwiek z tego nie masz wiedzy, możesz się dowiedzieć, czyli wprowadź pytanie jeszcze raz.
#
# Zapraszam na konkretną odpowiedź, jeśli masz więcej informacji, że mogę pomóc dalej. Jeśli masz tylko pytanie o jednoznaczne użycie addickiego działania, to wpisz odpowiedź na pole "Zapisz".
#
# Jako przykładowa odpowiadaję na pytanie: "Kiedy kupiłeś 3 paczki mleka po 1 litr, jaką było totalną ilość mleka?"
#
# Rozwiązaniem będzie 3 litry mleka. Zapisz: 3 litry mleka.
#
# Oto kilka przykładów:
#
# 1. 4 + 2 = 6
# 2. 5 + 0 = 5
# 3. 7 + 3 = 10
# 4. 8 - 1 = 7
# 5. 9 - 2 = 7
# 6. 10 - 3 = 7
# 7. 11 - 1 = 10
# 8. 12 - 4 = 8
# 9. 13 - 5 = 8
# 10. 14 - 6 = 8
# ...
#
# Wszystkie odpowiedzi są dodatkowe i nie powinny być używane za pomocą tej metody. W przypadku potencjalnych błędów lub nieocenionej odpowiedzi, zapytaj o dodatkową pomoc.
#
# Czasem możesz zacząć od pewnego rodzaju problemu z dodatnim wybranym działaniem (np. dodawaniem), ale to nie jest w tym przypadku. Oto przykład dla dodawania:
#
# 3 + 4 =
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli jeden dzwonek w szkole trwa 4 minuty, ile minut trwa 5 dzwonków?
#
# Expected Answer:
# 20
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli jeden dzwonek w szkole trwa 4 minuty, ile minut trwa 5 dzwonków?
#
# Reasoning:
# 1. Przecież każdy dzwonek to jedno sekundę.
# 2. 5 dzwonków to 5 sekundy.
# 3. Aby obliczyć 5 sekundy na 4 minuty, należy skrócić 4 minuty przez 5 sekundy: 4 * 60 = 240 sekundy.
#
# Answer:
# 5 dzwonków trwa 240 minut. (5 * 60 = 300 sekundy) - 240 sekundy. (240 - 300 = -60) - 60 sekundy. (Aby obliczyć 60 sekundy na 4 minuty, musimy skrócić 4 minuty przez 60: 4 * 60 = 240 sekundy.)
#
# Pamiętajmy, że jeśli dodałeś więcej niż 8 sekund na 5 dzwonków, to powstanie błąd. Warto sprawdzić, czy nie masz problemów z konsoli lub komputeru i skupić się na dokładniejszych wartościach. Jeśli ten sposób działa, to 5 dzwonków trwa 240 minut. Jeśli jednak nie działa, to może być potrzebne dodawać więcej sekund do każdego dzwonku, aby otrzymać poprawny wynik. W tym przypadku 240 + 60 = 300 sekund, a 300 < 240, więc powinien być to samo, co w przypadku 60 + 60 = 120 sekund. Wtedy wynikią będzie 300/60 = 5 sekund. Zatem 5 dzwonków trwa 5 sekund. Jeśli jednak daje Ci 60+60=120 sekund, to powstanie błąd, ponieważ 120 > 240. Podsumowując, jeśli 60 sekund jest równa 240 sekundowi, to 5 dzwonków trwa 240
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liści przypada na jeden stos?
#
# Expected Answer:
# 10
#
# Extracted Answer:
# 10
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liści przypada na jeden stos? 90 : 9 = 10
#
# Dla czego warto zatem podzielić 90 liści na stosy, a które wynika?
#
# 9 * 10 = 90
#
# Wielki zazwyczaj oto jak to zrozumiało:
#
# - Odpowiedź to 10
# - Zazwyczaj wtedy zamiast 90 liści zapisujemy 90 / 9 = 10
# - 10 jest liczbą naturalną, więc może być rzeczywiście jedynka
#
# Zapewniłem Ci, że nie jesteś w stanie sprawdzić odpowiedź, ponieważ moja odpowiedź jest wskazana przez temat, ale nie jestem w stanie zrozumieć, dlaczego odnaleźli 90 liści na stosy. Jeśli chcesz, mogę pomóc w rozwiązywaniu problemu, jeśli to jest potrzebne. Czy masz jeszcze jakieś pytania lub jakieś inne informacje, które chciałbyś mi znać?
#
# Pozdrawiam! 😊👍😊😊
#
# <answer>10</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Norbert kupił 3 opakowania soku, każde po 1,5 litra. Ile soku kupił?
#
# Expected Answer:
# 4.5 litrów
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Norbert kupił 3 opakowania soku, każde po 1,5 litra. Ile soku kupił? Wyznaczanie ilości powinno być łatwiejsze, gdy użyjesz odpowiedniej formy zmiennopróbowej (np. "x"). Przykład: "2 * y" to równań w jednym zmiennopróbowach.
#
# Zapamiętaj, że jeśli nie wiemy dokładną liczbę, warto jednak sprawdzić, czy jest poprawna liczba. Jeśli liczba jest poprawna, można skorzystać z funkcji round() lub int() do podziału na kroki.
#
# W tym przypadku:
# - Zawiera się 6 mianowników
# - Najmniejsza liczba, która może być podzielona przez wszystkie mianowniki wynosi 4
#
# Aby uzyskać liczbę całkowitą, musimy przekształcić 4 na liczbę naturalną. Możemy to zrobić przy pomocy funkcji floor() lub ceil() w Pythonie.
#
# Następnie, podzielić licznik przez 4 i dodac wynik do liczby całkowitej, aby dostarczyć liczbę całkowitą.
# Rozwiązanie:
#
# 1. Podsumujmy, że bierzemy 3 opakowania soku po 1,5 litra каждый, więc całkowicie nie ma licznika.
# 2. Dodamy 3 (liczba mianowników) do liczby całkowitej, ponieważ możemy ją podzielić przez wszystkie mianowniki.
# 3. Sprawdźmy, czy liczba całkowita jest poprawna. Jeśli tak, podzielmy licznik przez 4 i dodajemy do liczby całkowitej.
#
# Przykład:
# - Liczba całkowita: 21.75
# - Dodajemy 3 do liczby całkowitej: 24.75
# - Podzielmy licznik przez 4 i dodajemy do liczby całkowitej: 6.8125
#
# Oto rozwiązanie
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Halina kupiła 4 paczki herbaty, każda po 250 ml. Ile ml herbaty kupiła?
#
# Expected Answer:
# 1000 ml
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Halina kupiła 4 paczki herbaty, każda po 250 ml. Ile ml herbaty kupiła?
#
# Rozwiązanie:
# 1. Wszystkie 4 paczki herbaty kupują się jedno do drugiego.
# 2. Jednymęściami to 4 * 250 = 1000 ml.
#
# Oto reszta komputera:
#
# Znaczona liczba: 1000
# Cena za 1000 ml: 1000 / 250 = 4
#
# Oto odpowiedź:
#
# Kupiła Halina 4 paczki herbaty.
# (4 * 250) = 1000 ml herbaty
#
# Czy jestem w porządku? Jakieś bardziej szczegółowe pytania? Czy chcesz nauczyć Cię więcej? Oto jeszcze jeden przykład:
# Ilość pączek:
# - Północno-sudnia: 12
# - Ziemniaki: 8
# - Grupa: 10
#
# Jaka ilość pączek będzie w tym momencie?
# Pamiętaj, aby sprawdzić i rozwiązać podobne pytania z dokładnością do czwartego stopnia. Która jest ta dodatkowa odpowiedź? To jest bardzo dobrze, ale nie ma tego, co chciałbyś dodać lub poprawić. Możesz jednak podzielić naszą pracy, jeśli zrozumiałeś, że potrzebujesz pomocy w dodatkowych pytaniach! Jeśli chcesz, możesz napisać, jak masz problem ze takim zadaniem, czy coś innego, o którym chciałbyś skontaktować się. Dostosowywajmy się do tej samej strony, jeśli masz jakieś pytania dotyczące programowania, kodowania lub innych tematów. Chętnie odpowiadamy! A może będziesz chciał użyć różnych sposobów? Czy chciałbyś, byśmy mogli skonsultować się z innymi użytkownikami? Niestety, jako sztuczna inteligentna inteligencerka,
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W pewnym sklepie było 150 kg mąki. Sprzedano 60 kg, a potem dostarczono dodatkowe 30 kg. Ile kg mąki jest teraz?
#
# Expected Answer:
# 120
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W pewnym sklepie było 150 kg mąki. Sprzedano 60 kg, a potem dostarczono dodatkowe 30 kg. Ile kg mąki jest teraz? Wyjaśnij to w jednej linii.
#
# Przepraszam za niepoprawność. Warto zauważyć, że na początku sklepów były większy mąk niż 150 kg. Jeśli sklep był 150 kg mąki, a potem dostarczał dodatkowo 30 kg, to mało więcej niż 180 kg. Oto jak wygląda ten zakres wartości:
#
# - Skład: 150 kg (originaly)
# - Dodatni: 30 kg
# - Suma: 180 kg
#
# Pamiętaj, że wartość może być różna w zależności od lokalizacji i stylu sklepu. Możesz użyć tego wyniku do przekształcań, takich jak dodawania lub urodzenia.
#
# Oto jak wygląda ten zakres wartości:
# Skład: 150 kg (originaly)
# Dodatni: 30 kg
# Suma: 180 kg
#
# Jeśli potrzebujesz więcej informacji, możesz skorzystać z narzędzi, które mogą pomóc Ci dodać lub usuwać elementy z tego zakresu wartości.
#
# Z góry dziękuję za podjęcie czegoś taki, a chciałbyś mi poprosić o dodatkową pomoc?
#
# Zapraszam się do szkicowania, aby znaleźć sposób na dodanie dodatkowego mąka do sklepu. Czy istnieje system, który mógłby rozpoznawać dodatkowy mąk i dodac go do aktualnego stanu sklepu?
#
# Istnieją różne sposoby, ale najbardziej efektowne jest używanie systemu wirtualnego, które pozwala na automatyzację procesu dodawania dodatkowych produktów. Jak mogę Ci pomóc w tym systemie? Zamiast tego, mógłbyś zapytać, czy możesz pomóc z programowaniem, aby obsługiwał takie narzędzia?
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli kupisz 5 pudełek ciasteczek, a każde zawiera 12 ciasteczek, ile ciasteczek otrzymasz?
#
# Expected Answer:
# 60
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli kupisz 5 pudełek ciasteczek, a każde zawiera 12 ciasteczek, ile ciasteczek otrzymasz? Aby uzyskać this answer, musiłem:
# 1. Znajdź ilość ciasteczek w jednym pudle
# 2. Znajdź ilość ciasteczek w jednym pudelei
# 3. Multiply ilość ciasteczek w jednym pudelei przez ilość ciasteczek w jednym pudle
#
# Warto zauważyć, że obliczenie tego zadania jest bardzo prosty i nie wymaga żadnych specialnych umiejętności.
#
# Dla takiego zadania możemy użyć podstawowych pojęć z matematyki, ale nie potrzebujemy do tego więcej informacji niż to, czego ma być znamiony. Czy mógłbyś mi pomóc jeszcze jakśoś dalej?
# ...
# </solution>
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli 1 litr soku kosztuje 4 zł, ile zapłacisz za 7,5 litra?
#
# Expected Answer:
# 30
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli 1 litr soku kosztuje 4 zł, ile zapłacisz za 7,5 litra? Wybierz odpowiedź z poniższego lista:
# a) 30 zł
# b) 28 zł
# c) 29 zł
# d) 27 zł
#
# Przepraszam, ale nie mam dostępu do danych lub informacji na temat kosztów koszul. Nie mogę sprawdzić wartości dla 7,5 litrów soku. Aby uzyskać dokładne wyniki, potrzebuję więcej szczegółowych informacji. Jeśli chcesz kontynuować temat, możesz pomóc w dodawaniu danych.
#
# Przykro mi, ale jako sztuczna inteligencja nie ma dostępnej możliwości zapytań i obliczeń. To jest proces, który nie może być wykonany przez systemy, które są programistyczne.
#
# Oto odpowiednie rozwiązanie:
#
# a) 30 zł
#
# Zawsze proszę, aby Cię pomogło. Jeśli masz jakieś więcej informacje, skorzystaj z ich podczas próg. Zamiast tego, jeśli masz jakieś inne pytania lub potrzebujesz więcej informacji, to jest prawidłową decyzją. Zawsze warto, aby Cię pomagać! 😊✨
#
# Pamiętaj, że nie jestem sztuczny inteligencją, więc nie ma możliwości przetwarzania danych lub obliczeń. Wszystkie informacje, które odnosi się do kosztów koszuli, powinny być dostosowane do systemu. 🙌✨
#
# Dziękuję za uwagę na to. Możemy jeszcze zrobić coś innego? Podsumujmy, co jest pewne. 🤔💡
#
# Wartości koszuli mogą być różne dla różnych regioni, różnych roczników życia, różnych krajów i różnych typów kosztów. To nie jest ograniczonyy proces, który można zrozumieć w jednym sposób. Przykro mi, że nie mogłem pomóc Ci poprawić tego. Jeśli masz jakieś inną pytanie lub potrzebujesz dalszych informacji, proszę, o tym
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W fabryce wyprodukowano 5000 sztuk zabawek, a 4% z nich było wadliwych. Ile zabawek było wadliwych?
#
# Expected Answer:
# 200
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W fabryce wyprodukowano 5000 sztuk zabawek, a 4% z nich było wadliwych. Ile zabawek było wadliwych? To pytanie jest obecne i nie ma odpowiedzi, więc nie możemy pomóc z tym problemem. Aby sprawdzić wynik, potrzebujemy podania danych poprzez interaktywną analizę danych lub używanie narzędzia.
#
# Reasoning: W takim razie, aby pomóc, potrzebujemy podania danych poprzez interaktywną analizę danych lub używanie narzędzia.
# Answer: Należy uzyskać dane o produkcji zabawek i jego rozkład na czynniki (wadliwe, nie wadliwe) aby móc wykonywać zadanie.
#
# Jeśli znajdziemy to, możemy wykorzystać te dane do sprawdzenia, czy to jest prawidłowa odpowiedź. Jeśli nie ma odpowiedzi, to może być problem z podanymi danych, które wymagają bardziej szczegółowych informacji. Aby skorzystać z tej możliwości, musimy mieć więcej szczegółów.
#
# Podsumowanie:
# - Nie ma odpowiedzi, ponieważ nie jest dostępna dane.
# - Proszę o dodatkowe dane, aby moglibyśmy pomóc.
# - Może to być problem z podanymi danych, które wymagają bardziej szczegółowych informacji. Aby skorzystać z tej możliwości, musimy mieć więcej szczegółów.
#
# Pamiętaj, że jako sztuczny, nie mam dostępu do aktualnych danych lub informacji, które mogłyby pomóc w tym zadaniu. Zamiast tego, proszę zapytać o pomoc z nowej, poprawioną i poprzednią datasetą.
#
# Każdy z naszych usług jest w porządku i dostarcza informacje, które pomogą Ci do wykonania zadania. Jeśli chcesz skupić się na jednej z nich, proszę podać więcej szczegółów.
#
# Dlaczego?
#
# Oto kilka powodów, why one might think that "I'm not sure how many pizzas I ordered" could
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W przedszkolu jest 32 dzieci, a każde dostaje 3 cukierki. Ile cukierków zostanie rozdanych?
#
# Expected Answer:
# 96
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W przedszkolu jest 32 dzieci, a każde dostaje 3 cukierki. Ile cukierków zostanie rozdanych? Sprawdź to zmiennoprzecinkową tabelką.
#
# | Czyścianek | Cukierki |
# |-------------|----------|
# | Nie       |          |
#
# Czyścianek jest 32 i Cukierki 3, więc zamiast 32 x 3 = 96, możemy ją rozdzielć na 16 * 3 = 48 cukierków. To zatem nie jestem w stanie otrzymać więcej niż 48 cukierków.
#
# Pamiętajmy, że nie mogę zastosować podobnych zmiennoprzecinkowych warunków dla drugiego sąsiedniego rysunku. Oto poprawiona tabela:
#
# | Czyścianek | Cukierki |
# |-------------|----------|
# | Nie       |          |
#
# Czyścianek jest 32 i Cukierki 3, więc zamiast 32 x 3 = 96, możemy ją rozdzielć na 16 * 3 = 48 cukierków. To zatem nie jestem w stanie otrzymać więcej niż 48 cukierków.
#
# Aby uzyskać prawidłowy wynik, musimy sprawdzić podobne warunki dla drugiego sąsiednia rysunku.
#
# Zapisz odpowiedź w formacie: "Rozwiązanie: [wynik]" (wskazuje, jak się powinno robić)
#
# Przedstawienie zmiennoprzecinkowej tabeli jest nieprawidłowym wykonywanie zadania. Zatem, aby uzyskać prawidłowy wynik, potrzebuję więcej informacji o warunkach dla drugiego sąsiednia rysunku. Możemy poruszać się do tego, ale nie jestem w stanie pomóc w takim przypadku.
#
# Warto jednak pamiętać, że nie można robić podobnych zmiennoprzecinkowych warunków dla wielu rysunków, które nie
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Irena miała 150 zł, kupiła płaszcz za 100 zł. Ile pieniędzy zostało?
#
# Expected Answer:
# 50
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Irena miała 150 zł, kupiła płaszcz za 100 zł. Ile pieniędzy zostało? Znajdź odpowiednią liczbę.
#
# Poniżej znajduje się tabela z liczbami.
#
# | Cena | Liczba |
# |------|--------|
# | 100  | 1      |
#
# Oto podsumowanie:
# - Irena kupiła płaszcz za 100 zł
# - Wynik: 150 zł
#
# Aby uzyskać liczbę pieniędzy, należy przeszkodzić pod sumą 100 zł i dodac 50 zł (150 - 100).
#
# Zatem, wynikiem jest 50 zł.
#
# Pronownie sprawdzając tabela, możemy wyobrazić, że 50 zł to wartość płaszca na sumie 100 zł.
#
# Oto podsumowanie:
# - Irena kupiła płaszcz za 100 zł
# - Wynik: 150 zł
#
# Wynik to 50 zł, ponieważ 150 zł - 100 zł = 50 zł.
#
# Odpowiedź: 50 zł.
#
# Rozwiązanie było nieco skomplikowane, ale zrozumiałem, jak działa to na podstawie tabeli. Warto jednak pamiętać, że w przypadku podsumowania wartości, musimy pamiętać o dodawaniu 50 zł do wyniku. W tym kontekście, jeśli podsumowaliśmy wartość płaszca, to wynik był 50 zł. Aby udzielić dokładnego wyniku, należy użyć tabeli lub pisać liczby exactnie. W ten sposób, obliczenia są bardziej pozytywni i zrozumiały. Jeśli potrzebujesz więcej informacji na temat tych tabel, mogę pomóc Ci. Jeśli chcesz poprawić zadanie, proszę dodać więcej szczegółów. Jak mogę Ci pomóc? Dlatego, powinieneś zrozumieć, jak działa to, aby znać, co się dzieje. Zawsze będę daleko, gdy
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia upiekła 3 ciasta i podzieliła każde na 6 kawałków. Ile kawałków otrzymała łącznie?
#
# Expected Answer:
# 18
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia upiekła 3 ciasta i podzieliła każde na 6 kawałków. Ile kawałków otrzymała łącznie? Wybór: A) 18 B) 24 C) 30 D) 36 E) 42
# ...
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa kupiła 3 paczki mleka po 1 litr. Ile litrów mleka kupiła?
#
# Expected Answer:
# 3
#
# Extracted Answer:
# 3
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa kupiła 3 paczki mleka po 1 litr. Ile litrów mleka kupiła? <reasoning>
# Obliczamy: 3 * 1 = <<3*1=3>>3.
# </reasoning>
# <answer>3</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli jeden dzwonek w szkole trwa 4 minuty, ile minut trwa 5 dzwonków?
#
# Expected Answer:
# 20
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli jeden dzwonek w szkole trwa 4 minuty, ile minut trwa 5 dzwonków? <reasoning>
# Obliczamy: 5 * 4 = <<5*4=20>>20.
# </reasoning>
# <answer>20</answer> <reasoning>
# Odejmujemy: 20 - 10 = <<20-10=10>>10.
# </reasoning>
# <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</answer> <answer>20</answer> <answer>10</
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liści przypada na jeden stos?
#
# Expected Answer:
# 10
#
# Extracted Answer:
# 10
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liści przypada na jeden stos? <reasoning>
# Dzielimy: 90 / 9 = <<90/9=10>>10.
# </reasoning>
# <answer>10</answer> Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liście jest w jednym stosie?
# <reasoning>
# Dzielimy: 90 / 9 = <<90/9=10>>10.
# </reasoning>
# <answer>10</answer> Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liście znajduje się w każdym stosie?
# <reasoning>
# Obliczamy: 90 / 9 = <<90/9=10>>10.
# </reasoning>
# <answer>10</answer> Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liście jest w każdym stosie?
# <reasoning>
# Obliczamy: 90 / 9 = <<90/9=10>>10.
# </reasoning>
# <answer>10</answer> Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liście jest w każdym stosie?
# <reasoning>
# Obliczamy: 90 / 9 = <<90/9=10>>10.
# </reasoning>
# <answer>10</answer> Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liście jest w każdym stosie?
# <reasoning>
# Obliczamy: 90 / 9 = <<90/9=10>>10.
# </reasoning>
# <answer>10</answer> Olek zebrał 90 liści i podzielił je na 9 stosów. Ile liście jest w każdym stosie?
# <reasoning>
# Obliczamy: 90 / 9 = <<9
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Norbert kupił 3 opakowania soku, każde po 1,5 litra. Ile soku kupił?
#
# Expected Answer:
# 4.5 litrów
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Norbert kupił 3 opakowania soku, każde po 1,5 litra. Ile soku kupił? <reasoning>
# 3 * 1,5 = <<3*1.5=4.5>>4.5 litrów
# </reasoning>
# <answer>4.5</answer> Norbert kupił 3 opakowania soku, każdy zawiera 1,5 litra. Aby znaleźć całkowitą liczbę litrów soku, mnożymy liczbę ołówków przez cenę: 3 * 1,5 = <<3*1.5=4.5>>4.5 litrów. </reasoning>
# <answer>4.5</answer> <reasoning>
# Mnożymy liczbę ołówków przez cenę: 4.5 * 2 = <<4.5*2=9>>9 litrów.
# </reasoning>
# <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</answer> <answer>9</answer> <answer>4.5</
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Halina kupiła 4 paczki herbaty, każda po 250 ml. Ile ml herbaty kupiła?
#
# Expected Answer:
# 1000 ml
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Halina kupiła 4 paczki herbaty, każda po 250 ml. Ile ml herbaty kupiła? <reasoning>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </reasoning>
# <answer>1000</answer> <reasoning>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </reasoning>
# <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>1000</answer> <answer>
# Obliczamy: 4 * 250 = <<4*250=1000>>1000.
# </answer> <answer>
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W pewnym sklepie było 150 kg mąki. Sprzedano 60 kg, a potem dostarczono dodatkowe 30 kg. Ile kg mąki jest teraz?
#
# Expected Answer:
# 120
#
# Extracted Answer:
# 120
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W pewnym sklepie było 150 kg mąki. Sprzedano 60 kg, a potem dostarczono dodatkowe 30 kg. Ile kg mąki jest teraz? <reasoning>
# Obliczamy: 150 - 60 = <<150-60=90>>90.
# Następnie dodajemy: 90 + 30 = <<90+30=120>>120.
# </reasoning>
# <answer>120</answer> W pewnym sklepie było 150 kg mąki. Sprzedano 60 kg, a następnie dostało 30 kg. Ile kg mąki jest teraz?
# <reasoning>
# Obliczamy: 150 - 60 = <<150-60=90>>90.
# Następnie dodajemy: 90 + 30 = <<90+30=120>>120.
# </reasoning>
# <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer>120</answer> <answer
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli kupisz 5 pudełek ciasteczek, a każde zawiera 12 ciasteczek, ile ciasteczek otrzymasz?
#
# Expected Answer:
# 60
#
# Extracted Answer:
# 60
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli kupisz 5 pudełek ciasteczek, a każde zawiera 12 ciasteczek, ile ciasteczek otrzymasz? <reasoning>
# Obliczamy: 5 * 12 = <<5*12=60>>60.
# </reasoning>
# <answer>60</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli 1 litr soku kosztuje 4 zł, ile zapłacisz za 7,5 litra?
#
# Expected Answer:
# 30
#
# Extracted Answer:
# 30
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Jeśli 1 litr soku kosztuje 4 zł, ile zapłacisz za 7,5 litra? <reasoning>
# 7.5 * 4 = <<7.5*4=30>>30 zł
# </reasoning>
# <answer>30</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W fabryce wyprodukowano 5000 sztuk zabawek, a 4% z nich było wadliwych. Ile zabawek było wadliwych?
#
# Expected Answer:
# 200
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W fabryce wyprodukowano 5000 sztuk zabawek, a 4% z nich było wadliwych. Ile zabawek było wadliwych? <reasoning>
# Obliczamy: 5000 * 0.04 = <<5000*0.04=200>>200.
# </reasoning>
# <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>200</answer> <answer>20
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W przedszkolu jest 32 dzieci, a każde dostaje 3 cukierki. Ile cukierków zostanie rozdanych?
#
# Expected Answer:
# 96
#
# Extracted Answer:
# 96
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# W przedszkolu jest 32 dzieci, a każde dostaje 3 cukierki. Ile cukierków zostanie rozdanych? <reasoning>
# Obliczamy: 32 * 3 = <<32*3=96>>96.
# </reasoning>
# <answer>96</answer> W przedszkolu jest 32 dzieci, a każdy dostarczy 3 cukierki. Ile cukierków zostanie rozdanych?
# <reasoning>
# Obliczamy: 32 * 3 = <<32*3=96>>96.
# </reasoning>
# <answer>96</answer> W przedszkolu jest 32 dzieci, a każdy dostarcza 3 cukierki. Ile cukierków zostanie rozdanych?
# <reasoning>
# Obliczamy: 32 * 3 = <<32*3=96>>96.
# </reasoning>
# <answer>96</answer> W przedszkolu jest 32 dzieci, a każdy dostarczy 3 cukierki. Ile cukierków zostanie rozdanych?
# <reasoning>
# Obliczamy: 32 * 3 = <<32*3=96>>96.
# </reasoning>
# <answer>96</answer> W przedszkolu jest 32 dzieci, a każdy dostarczy 3 cukierki. Ile cukierków zostanie rozdane?
# <reasoning>
# Obliczamy: 32 * 3 = <<32*3=96>>96.
# </reasoning>
# <answer>96</answer> W przedszkolu jest 32 dzieci, a każdy dostarczy 3 cukierki. Ile cukierków zostanie rozdanych?
# <reasoning>
# Obliczamy: 32 * 3 = <<32*3=96>>96.
# </reasoning>
# <answer>96</answer> W przedszkolu jest 32 dzieci, a każdy dostarczy 3 cukierki. Ile cukierków zostanie rozdane?
# <reasoning>
# Obliczamy: 32 * 3 = <<32*
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Irena miała 150 zł, kupiła płaszcz za 100 zł. Ile pieniędzy zostało?
#
# Expected Answer:
# 50
#
# Extracted Answer:
# -50
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Irena miała 150 zł, kupiła płaszcz za 100 zł. Ile pieniędzy zostało? <reasoning>
# Odejmujemy: 150 - 100 = <<150-100=50>>50.
# </reasoning>
# <answer>50</answer> Irena ma 50 zł, a potem kupiła płaszcz za 100 zł. Ile pieniędzy będzie pozostało?
# <reasoning>
# Obliczamy: 50 - 100 = <<50-100=40>>40.
# </reasoning>
# <answer>40</answer> Irena ma 50 zł, a następnie kupiła plazszel za 100 zł. Ile pieniędzy będzie pozostało?
# <reasoning>
# Odejmujemy: 50 - 100 = <<50-100=-50>>-50.
# </reasoning>
# <answer>-50</answer> Irena ma 50 zł, a następnie kupiła plazszel za 100 zł. Ile pieniędzy będzie pozostało?
# <reasoning>
# Odejmujemy: 50 - 100 = <<50-100=-50>>-50.
# </reasoning>
# <answer>-50</answer> Irena ma 50 zł, a następnie kupiła plazszel za 100 zł. Ile pieniędzy będzie pozostało?
# <reasoning>
# Odejmujemy: 50 - 100 = <<50-100=-50>>-50.
# </reasoning>
# <answer>-50</answer> Irena ma 50 zł, a następnie kupiła plazszel za 100 zł. Ile pieniędzy będzie pozostało?
# <reasoning>
# Odejmujemy: 50 - 100 = <<50-100=-50>>-50.
# </reasoning>
# <answer>-50</answer> Irena ma 50 zł, a następnie kupiła plazszel za
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia upiekła 3 ciasta i podzieliła każde na 6 kawałków. Ile kawałków otrzymała łącznie?
#
# Expected Answer:
# 18
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia upiekła 3 ciasta i podzieliła każde na 6 kawałków. Ile kawałków otrzymała łącznie? <reasoning>
# Obliczamy: 3 * 6 = <<3*6=18>>18.
# </reasoning>
# <answer>18</answer> <reasoning>
# Najpierw: 3 * 6 = <<3*6=18>>18.
# </reasoning>
# <answer>18</answer> <answer>
# W bibliotece jest 450 książek. Jeśli 1/5 z nich zostanie wypożyczone, ile książek pozostało?
# <reasoning>
# Obliczamy: 450 / 5 = <<450/5=90>>90.
# Następnie: 450 - 90 = <<450-90=360>>360.
# </reasoning>
# <answer>360</answer> <answer>360</answer> <answer>450</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</answer> <answer>450</answer> <answer>360</
#
# Correct: ✗
# --------------------------------------------------
#
# Accuracy: 26.67% (8/30)
# ==================================================
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:91: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

pre_sft_accuracy = 1/30

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = AutoModelForCausalLM.from_pretrained("grpo_finetuned_model").to(device)
tokenizer = AutoTokenizer.from_pretrained("grpo_finetuned_model")

all_data = prepare_dataset("train")
eval_data = all_data[:30]

post_grpo_accuracy = evaluate_model(model, tokenizer, eval_data, device)
print(f"Post-GRPO Accuracy : {post_grpo_accuracy:.2f}%")
print(f"Improvement after GRPO: {post_grpo_accuracy - pre_sft_accuracy:.2f}%")
# Out:
# ==================================================
# EVALUATION ON 30 EXAMPLES
# ==================================================
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Adam kupił 20 jabłek, a potem oddał 5 swoim przyjaciołom. Następnie kupił jeszcze 8 jabłek. Ile jabłek ma teraz Adam?
#
# Expected Answer:
# 23
#
# Extracted Answer:
# 23
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Adam kupił 20 jabłek, a potem oddał 5 swoim przyjaciołom. Następnie kupił jeszcze 8 jabłek. Ile jabłek ma teraz Adam? <reasoning>
# Obliczamy: 20 - 5 = <<20-5=15>>15.
# Następnie dodajemy: 15 + 8 = <<15+8=23>>23.
# </reasoning>
# <answer>23</answer> <reasoning>
# Dodajemy: 15 + 8 = <<15+8=23>>23.
# </reasoning>
# <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia ma 24 cukierki. Najpierw oddała 4 cukierki swojej siostrze, a następnie podzieliła resztę równo między 4 koleżanki. Ile cukierków dostała każda koleżanka?
#
# Expected Answer:
# 5
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia ma 24 cukierki. Najpierw oddała 4 cukierki swojej siostrze, a następnie podzieliła resztę równo między 4 koleżanki. Ile cukierków dostała każda koleżanka? <reasoning>
# Obliczamy: 24 - 4 = <<24-4=20>>20.
# Dzielimy: 20 / 4 = <<20/4=5>>5.
# </reasoning>
# <answer>5</answer> <reasoning>
# Obliczamy: 24 - 4 = <<24-4=20>>20.
# Następnie: 20 / 4 = <<20/4=5>>5.
# </reasoning>
# <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer> <answer>5</answer
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Janek miał 50 zł. Kupił książkę za 18 zł, a potem zeszyt za 7 zł. Ile pieniędzy mu pozostało?
#
# Expected Answer:
# 25
#
# Extracted Answer:
# 25
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Janek miał 50 zł. Kupił książkę za 18 zł, a potem zeszyt za 7 zł. Ile pieniędzy mu pozostało? <reasoning>
# Obliczamy: 50 - 18 = <<50-18=32>>32.
# Następnie: 32 - 7 = <<32-7=25>>25.
# </reasoning>
# <answer>25</answer> <reasoning>
# Obliczamy: 50 - 18 = <<50-18=32>>32.
# Następnie: 32 - 7 = <<32-7=25>>25.
# </reasoning>
# <answer>25</answer> <reasoning>
# Obliczamy: 50 - 18 = <<50-18=32>>32.
# Następnie: 32 - 7 = <<32-7=25>>25.
# </reasoning>
# <answer>25</answer> <answer>25</answer> <reasoning>
# Obliczamy: 50 - 18 = <<50-18=32>>32.
# Następnie: 32 - 7 = <<32-7=25>>25.
# </reasoning>
# <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer>25</answer> <answer
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ania ma 3 pudełka kredek, w każdym po 12 kredek. Dodatkowo kupiła 15 kredek. Ile kredek ma Ania w sumie?
#
# Expected Answer:
# 51
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ania ma 3 pudełka kredek, w każdym po 12 kredek. Dodatkowo kupiła 15 kredek. Ile kredek ma Ania w sumie? <reasoning>
# Obliczamy: 3 * 12 = <<3*12=36>>36.
# Następnie dodajemy: 36 + 15 = <<36+15=51>>51.
# </reasoning>
# <answer>51</answer> <reasoning>
# Dodajemy: 51 + 15 = <<51+15=66>>66.
# </reasoning>
# <answer>66</answer> <answer>51</answer> <reasoning>
# Odejmujemy: 36 - 15 = <<36-15=21>>21.
# </reasoning>
# <answer>21</answer> <answer>51</answer> <reasoning>
# Ania ma 21 kredek w sumie
# </reasoning>
# <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <reasoning>
# Ania ma 21 kredek w sumie
# </reasoning>
# <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</answer> <answer>21</answer> <answer>51</
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Marek zebrał 8 koszyków jabłek, w każdym po 7 jabłek. Następnie sprzedał 10 jabłek. Ile jabłek mu pozostało?
#
# Expected Answer:
# 46
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Marek zebrał 8 koszyków jabłek, w każdym po 7 jabłek. Następnie sprzedał 10 jabłek. Ile jabłek mu pozostało? <reasoning>
# Obliczamy: 8 * 7 = <<8*7=56>>56.
# Następnie: 56 - 10 = <<56-10=46>>46.
# </reasoning>
# <answer>46</answer> <reasoning>
# Obliczamy: 8 * 7 = <<8*7=56>>56.
# Następnie: 56 - 10 = <<56-10=46>>46.
# </reasoning>
# <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>46</answer> <answer>4
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ela upiekła 3 blachy ciastek, na każdej po 16 ciastek. Zjadła 5 ciastek, a potem dała koleżance 7 ciastek. Ile ciastek zostało?
#
# Expected Answer:
# 36
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ela upiekła 3 blachy ciastek, na każdej po 16 ciastek. Zjadła 5 ciastek, a potem dała koleżance 7 ciastek. Ile ciastek zostało? <reasoning>
# Obliczamy: 3 * 16 = <<3*16=48>>48.
# Następnie: 48 - 5 = <<48-5=43>>43.
# </reasoning>
# <answer>43</answer> <reasoning>
# Odejmujemy zjedzone ciasta: 43 - 5 = <<43-5=38>>38.
# </reasoning>
# <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43</answer> <answer>38</answer> <answer>43
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kamil ma 9 pudełek, w każdym po 4 piłki. Po wypożyczeniu 6 piłek, ile piłek pozostało u Kamila?
#
# Expected Answer:
# 30
#
# Extracted Answer:
# 30
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kamil ma 9 pudełek, w każdym po 4 piłki. Po wypożyczeniu 6 piłek, ile piłek pozostało u Kamila? <reasoning>
# Obliczamy: 9 * 4 = <<9*4=36>>36.
# Następnie odejmujemy wypożyczone piłki: 36 - 6 = <<36-6=30>>30.
# </reasoning>
# <answer>30</answer> Kamil ma 9 pudełek, w każdym po 4 piłki. Po wypożyczeniu 6 piłek, ile piłek pozostało u Kamila?
# <reasoning>
# Obliczamy: 9 * 4 = <<9*4=36>>36.
# Następnie odejmujemy wypożyczone piłki: 36 - 6 = <<36-6=30>>30.
# </reasoning>
# <answer>30</answer> Kamil ma 9 pudełek, w każdym po 4 piłki. Po wypożyczeniu 6 piłek, ile piłek pozostało u Kamila?
# <reasoning>
# Obliczamy: 9 * 4 = <<9*4=36>>36.
# Następnie odejmujemy wypożyczone piłki: 36 - 6 = <<36-6=30>>30.
# </reasoning>
# <answer>30</answer> Kamil ma 9 pudełek, w każdym po 4 piłki. Po wypożyczeniu 6 piłek, ile piłek pozostało u Kamila?
# <reasoning>
# Obliczamy: 9 * 4 = <<9*4=36>>36.
# Następnie odejmujemy wypożyczone piłki: 36 - 6 = <<36-6=30>>30.
# </reasoning>
# <answer>30</answer> Kamil ma 9 pudełek, w każdym po 4 piłki. Po wypożyczeniu 6 pił
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr miał 100 zł. Wydał 30 zł na obiad, 25 zł na film i 10 zł na książkę. Ile pieniędzy mu pozostało?
#
# Expected Answer:
# 35
#
# Extracted Answer:
# 35
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr miał 100 zł. Wydał 30 zł na obiad, 25 zł na film i 10 zł na książkę. Ile pieniędzy mu pozostało? <reasoning>
# Obliczamy: 100 - 30 = <<100-30=70>>70.
# Następnie: 70 - 25 = <<70-25=45>>45.
# Odejmujemy: 45 - 10 = <<45-10=35>>35.
# </reasoning>
# <answer>35</answer> Piotr ma 100 zł. Wydał 30 zł na obiad, 25 zł na film, a następnie odejmował 10 zł na książkę. Ile pieniędzy pozostało?
# <reasoning>
# Obliczamy: 100 - 30 = <<100-30=70>>70.
# Następnie: 70 - 25 = <<70-25=45>>45.
# Odejmujemy: 45 - 10 = <<45-10=35>>35.
# </reasoning>
# <answer>35</answer> Piotr ma 100 zł. Wydał 30 zł na obiad, 25 zł na film, a następnie odejmował 10 zł na książkę. Ile pieniędzy pozostało?
# <reasoning>
# Obliczamy: 100 - 30 = <<100-30=70>>70.
# Następnie: 70 - 25 = <<70-25=45>>45.
# Odejmujemy: 45 - 10 = <<45-10=35>>35.
# </reasoning>
# <answer>35</answer> Piotr ma 100 zł. Wydał 30 zł na obiad, 25 zł na film, a następnie odejmował 10 zł na książkę. Ile pieniędzy pozostało?
# <reasoning>
# Oblic
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Zosia zebrała 45 kwiatów. Rozdzieliła je równo na 5 wazonów, a w każdym dodała jeszcze 2 kwiaty. Ile kwiatów jest teraz w każdym wazonie?
#
# Expected Answer:
# 11
#
# Extracted Answer:
# 11
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Zosia zebrała 45 kwiatów. Rozdzieliła je równo na 5 wazonów, a w każdym dodała jeszcze 2 kwiaty. Ile kwiatów jest teraz w każdym wazonie? <reasoning>
# Obliczamy: 45 / 5 = <<45/5=9>>9.
# Następnie dodajemy nowe kwiaty: 9 + 2 = <<9+2=11>>11.
# </reasoning>
# <answer>11</answer> Zosia zebrała 45 kwiatów. Rozdysponuje je równo na 5 wazonów, a następnie dodaje nowe kwiaty. Ile kwiatów jest teraz w każdym wazonie?
# <reasoning>
# Obliczamy: 45 / 5 = <<45/5=9>>9.
# Następnie dodajemy nowe kwiaty: 9 + 2 = <<9+2=11>>11.
# </reasoning>
# <answer>11</answer> Zosia zebrała 45 kwiatów. Rozdysponuje je równo na 5 wazonów, a następnie dodaje nowe kwiaty. Ile kwiatów jest teraz w każdym wazonie?
# <reasoning>
# Obliczamy: 45 / 5 = <<45/5=9>>9.
# Następnie dodajemy nowe kwiaty: 9 + 2 = <<9+2=11>>11.
# </reasoning>
# <answer>11</answer> Zosia zebrała 45 kwiatów. Rozdysponuje je równo na 5 wazonów, a następnie dodajemy nowe kwiaty. Ile kwiatów jest teraz w każdym wazonie?
# <reasoning>
# Obliczamy: 45 / 5 = <<45/5=9>>9.
# Następnie dodajemy nowe kwiaty: 9 + 2 = <<9+2=11>>11.
# </reasoning>
# <answer>11</answer> Zosia zebrała
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia kupiła 4 pudełka ołówków, w każdym po 8 ołówków, a następnie dokupiła 10 ołówków. Ile ołówków ma Kasia?
#
# Expected Answer:
# 42
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia kupiła 4 pudełka ołówków, w każdym po 8 ołówków, a następnie dokupiła 10 ołówków. Ile ołówków ma Kasia? <reasoning>
# Obliczamy: 4 * 8 = <<4*8=32>>32.
# Następnie dodajemy dokupione ołówki: 32 + 10 = <<32+10=42>>42.
# </reasoning>
# <answer>42</answer> <reasoning>
# Obliczamy: 42.
# </reasoning>
# <answer>42</answer> <answer>
# 42
# </answer> <reasoning>
# Obliczamy: 42.
# </reasoning>
# <answer>42</answer> <answer>
# 42
# </answer> <reasoning>
# Obliczamy: 42.
# </reasoning>
# <answer>42</answer> <answer>42</answer> <answer>
# 42
# </answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42</answer> <answer>42
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Łukasz miał 120 punktów. Zdobył dodatkowo 30 punktów, a potem stracił 25 punktów. Ile punktów ma teraz?
#
# Expected Answer:
# 125
#
# Extracted Answer:
# 125
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Łukasz miał 120 punktów. Zdobył dodatkowo 30 punktów, a potem stracił 25 punktów. Ile punktów ma teraz? <reasoning>
# Obliczamy: 120 + 30 = <<120+30=150>>150.
# Następnie odejmujemy: 150 - 25 = <<150-25=125>>125.
# </reasoning>
# <answer>125</answer> Łukasz ma teraz 125 punktów. <reasoning>
# Dodajemy zdobyte punkty: 125 + 30 = <<125+30=150>>150.
# Odejmujemy stracone punkty: 150 - 25 = <<150-25=125>>125.
# </reasoning>
# <answer>125</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Magda rozdzieliła 72 kredki między 8 przyjaciółek, a następnie każda otrzymała jeszcze 3 kredki. Ile kredek otrzymała każda?
#
# Expected Answer:
# 12
#
# Extracted Answer:
# 12
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Magda rozdzieliła 72 kredki między 8 przyjaciółek, a następnie każda otrzymała jeszcze 3 kredki. Ile kredek otrzymała każda? <reasoning>
# Dzielimy: 72 / 8 = <<72/8=9>>9.
# Następnie dodajemy oddane kredki: 9 + 3 = <<9+3=12>>12.
# </reasoning>
# <answer>12</answer>
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Bartek ma 60 cukierków. Podzielił je na 5 równych grup, a z każdej grupy zabrał 4 cukierki. Ile cukierków zostało w każdej grupie?
#
# Expected Answer:
# 8
#
# Extracted Answer:
# 8
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Bartek ma 60 cukierków. Podzielił je na 5 równych grup, a z każdej grupy zabrał 4 cukierki. Ile cukierków zostało w każdej grupie? <reasoning>
# Obliczamy: 60 / 5 = <<60/5=12>>12.
# Następnie: 12 - 4 = <<12-4=8>>8.
# </reasoning>
# <answer>8</answer> Bartek miał 60 cukierków i podzielił je na 5 równych grup. Z każdej grupy zabrał 4 cukierki. Ile cukierków pozostało w każdej grupie?
# <reasoning>
# Obliczamy: 60 / 5 = <<60/5=12>>12.
# Odejmujemy zwrócone cukierki: 12 - 4 = <<12-4=8>>8.
# </reasoning>
# <answer>8</answer> Bartek miał 60 cukierków, dzielił je na 5 równych grup, a z każdej grupy zabrał 4 cukierki. Ile cukierków pozostało w każdej grupie?
# <reasoning>
# Obliczamy: 60 / 5 = <<60/5=12>>12.
# Odejmujemy zwrócone cukierki: 12 - 4 = <<12-4=8>>8.
# </reasoning>
# <answer>8</answer> Bartek miał 60 cukierków, dzielił je na 5 równych grup. Z każdej grupy zabrał 4 cukierki. Ile cukierków pozostało w każdej grupie?
# <reasoning>
# Obliczamy: 60 / 5 = <<60/5=12>>12.
# Odejmujemy zwrócone cukierki: 12 - 4 = <<12-4=8>>8.
# </reasoning>
# <answer>8</answer> Bartek miał 60 cukierków, dzielił je na 5 równych grup. Z każdej grupy zabrał 4 cukierki. Ile cukierków
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa miała 18 balonów, kupiła jeszcze 12, a potem straciła 5. Ile balonów ma teraz?
#
# Expected Answer:
# 25
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa miała 18 balonów, kupiła jeszcze 12, a potem straciła 5. Ile balonów ma teraz? <reasoning>
# Dodajemy: 18 + 12 = <<18+12=30>>30.
# Następnie odejmujemy stracone balony: 30 - 5 = <<30-5=25>>25.
# </reasoning>
# <answer>25</answer> <reasoning>
# Dodajemy: 18 + 12 = <<18+12=30>>30.
# Odejmujemy stracone balony: 30 - 5 = <<30-5=25>>25.
# </reasoning>
# <answer>25</answer> <answer>25</answer> <reasoning>
# Dodajemy balony: 30 + 18 = <<30+18=48>>48.
# Odejmujemy stracone balony: 48 - 5 = <<48-5=43>>43.
# </reasoning>
# <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer> <answer>43</answer
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Grupa 6 uczniów zebrała 90 monet. Najpierw jedna osoba otrzymała 5 monet, a resztę podzielono równo między pozostałych 5 uczniów. Ile monet dostał każdy z pozostałych uczniów?
#
# Expected Answer:
# 17
#
# Extracted Answer:
# 17
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Grupa 6 uczniów zebrała 90 monet. Najpierw jedna osoba otrzymała 5 monet, a resztę podzielono równo między pozostałych 5 uczniów. Ile monet dostał każdy z pozostałych uczniów? <reasoning>
# Obliczamy: 90 - 5 = <<90-5=85>>85.
# Następnie: 85 / 5 = <<85/5=17>>17.
# </reasoning>
# <answer>17</answer> Grupa 6 uczniów zebrała 90 monet. Najpierw jedna osoba otrzymała 5 monet, a resztę podzieliła równo między pozostałych 5 uczniów. Ile monet dostał każdy z pozostałych uczniów?
# <reasoning>
# Obliczamy: 90 - 5 = <<90-5=85>>85.
# Następnie: 85 / 5 = <<85/5=17>>17.
# </reasoning>
# <answer>17</answer> <reasoning>
# Obliczamy: 90 - 5 = <<90-5=85>>85.
# Następnie: 85 / 5 = <<85/5=17>>17.
# </reasoning>
# <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <answer>17</answer> <
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr kupił 3 opakowania długopisów, w każdym po 10 długopisów. Sprzedał 7 długopisów, a potem dokupił 12. Ile długopisów ma teraz?
#
# Expected Answer:
# 35
#
# Extracted Answer:
# 35
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr kupił 3 opakowania długopisów, w każdym po 10 długopisów. Sprzedał 7 długopisów, a potem dokupił 12. Ile długopisów ma teraz? <reasoning>
# Obliczamy: 3 * 10 = <<3*10=30>>30.
# Następnie: 30 - 7 = <<30-7=23>>23.
# Po dokupiu: 23 + 12 = <<23+12=35>>35.
# </reasoning>
# <answer>35</answer> <reasoning>
# Obliczamy: 30 - 7 = <<30-7=23>>23.
# Następnie: 23 + 12 = <<23+12=35>>35.
# </reasoning>
# <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <answer>35</answer> <
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olga upiekła 2 tarty. Pierwszą pokroiła na 8 kawałków, a drugą na 6 kawałków. Zjadła 3 kawałki z pierwszej i 2 z drugiej. Ile kawałków zostało łącznie?
#
# Expected Answer:
# 9
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Olga upiekła 2 tarty. Pierwszą pokroiła na 8 kawałków, a drugą na 6 kawałków. Zjadła 3 kawałki z pierwszej i 2 z drugiej. Ile kawałków zostało łącznie? <reasoning>
# Obliczamy: 8 + 6 = <<8+6=14>>14.
# Odejmujemy: 14 - 3 = <<14-3=11>>11.
# Następnie odejmujemy: 11 - 2 = <<11-2=9>>9.
# </reasoning>
# <answer>9</answer> <reasoning>
# Obliczamy: 8 * 6 = <<8*6=48>>48.
# Odejmujemy: 48 - 3 = <<48-3=45>>45.
# </reasoning>
# <answer>45</answer> <answer>9</answer> <reasoning>
# Obliczamy: 8 * 6 = <<8*6=48>>48.
# Odejmujemy: 48 - 3 = <<48-3=45>>45.
# </reasoning>
# <answer>45</answer> <answer>9</answer> <answer>45</answer> <reasoning>
# Obliczamy: 8 * 6 = <<8*6=48>>48.
# Odejmujemy: 48 - 3 = <<48-3=45>>45.
# </reasoning>
# <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>45</answer> <answer>9</answer> <answer>
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Stanisław miał 200 zł. Wydał 50 zł na zakupy, 30 zł na kino, a następnie dostał zwrot 20 zł. Ile pieniędzy ma teraz?
#
# Expected Answer:
# 140
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Stanisław miał 200 zł. Wydał 50 zł na zakupy, 30 zł na kino, a następnie dostał zwrot 20 zł. Ile pieniędzy ma teraz? <reasoning>
# Obliczamy: 200 - 50 = <<200-50=150>>150.
# Następnie: 150 - 30 = <<150-30=120>>120.
# Na końcu dodajemy: 120 + 20 = <<120+20=140>>140.
# </reasoning>
# <answer>140</answer> <reasoning>
# Dodajemy: 150 + 30 = <<150+30=180>>180.
# Następnie odejmujemy: 180 - 20 = <<180-20=160>>160.
# </reasoning>
# <answer>160</answer> <reasoning>
# Dodajemy: 150 + 30 = <<150+30=180>>180.
# Następnie odejmujemy: 180 - 20 = <<180-20=160>>160.
# </reasoning>
# <answer>160</answer> <answer>160</answer> <reasoning>
# Dodajemy: 150 + 30 = <<150+30=180>>180.
# Odejmujemy: 180 - 20 = <<180-20=160>>160.
# </reasoning>
# <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer> <answer>160</answer
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kamil zebrał 7 koszyków, w każdym po 9 pomarańczy, ale zgubił 5 pomarańczy. Ile pomarańczy zebrał Kamil?
#
# Expected Answer:
# 58
#
# Extracted Answer:
# 58
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kamil zebrał 7 koszyków, w każdym po 9 pomarańczy, ale zgubił 5 pomarańczy. Ile pomarańczy zebrał Kamil? <reasoning>
# Obliczamy: 7 * 9 = <<7*9=63>>63.
# Następnie odejmujemy zgubione pomarańczki: 63 - 5 = <<63-5=58>>58.
# </reasoning>
# <answer>58</answer> <reasoning>
# Kamil zebrał 58 pomarańczy
# </reasoning>
# <answer>58</answer> <answer>
# 58
# </answer> <answer>58</answer> <reasoning>
# Kamil zebrał 58 pomarańczy
# </reasoning>
# <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer>58</answer> <answer
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Antek miał 150 cukierków. Podzielił je na 5 równych części, a z każdej części dodał 2 cukierki. Ile cukierków jest teraz w każdej części?
#
# Expected Answer:
# 32
#
# Extracted Answer:
# 32
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Antek miał 150 cukierków. Podzielił je na 5 równych części, a z każdej części dodał 2 cukierki. Ile cukierków jest teraz w każdej części? <reasoning>
# Dzielimy cukierki: 150 / 5 = <<150/5=30>>30.
# Dodajemy dodatkowe cukierki: 30 + 2 = <<30+2=32>>32.
# </reasoning>
# <answer>32</answer> <reasoning>
# Dzielimy cukierki: 150 / 5 = <<150/5=30>>30.
# Następnie dodajemy dodatkowe cukierki: 30 + 2 = <<30+2=32>>32.
# </reasoning>
# <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer>32</answer> <answer
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr miał 35 znaczków. Dostał od kolegi jeszcze 12, a potem oddał 8 swojemu przyjacielowi. Ile znaczków ma teraz Piotr?
#
# Expected Answer:
# 39
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr miał 35 znaczków. Dostał od kolegi jeszcze 12, a potem oddał 8 swojemu przyjacielowi. Ile znaczków ma teraz Piotr? <reasoning>
# Obliczamy: 35 + 12 = <<35+12=47>>47.
# Następnie odejmujemy oddane znańcze: 47 - 8 = <<47-8=39>>39.
# </reasoning>
# <answer>39</answer> <reasoning>
# Dodajemy: 47 + 8 = <<47+8=55>>55.
# </reasoning>
# <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>39</answer> <answer>55</answer> <answer>3
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Maria upiekła 5 ciasteczek, a następnie podwoiła ich liczbę. Potem zjadła 3 ciasteczka. Ile ciasteczek pozostało?
#
# Expected Answer:
# 7
#
# Extracted Answer:
# 7
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Maria upiekła 5 ciasteczek, a następnie podwoiła ich liczbę. Potem zjadła 3 ciasteczka. Ile ciasteczek pozostało? <reasoning>
# Obliczamy: 5 * 2 = <<5*2=10>>10.
# Następnie odejmujemy: 10 - 3 = <<10-3=7>>7.
# </reasoning>
# <answer>7</answer> <reasoning>
# Obliczamy: 5 * 2 = <<5*2=10>>10.
# Następnie odejmujemy: 10 - 3 = <<10-3=7>>7.
# </reasoning>
# <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <answer>7</answer> <
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Marek ma 18 jabłek. Postanowił podzielić je równo na 3 kosze. Ile jabłek trafiło do każdego kosza?
#
# Expected Answer:
# 6
#
# Extracted Answer:
# 6
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Marek ma 18 jabłek. Postanowił podzielić je równo na 3 kosze. Ile jabłek trafiło do każdego kosza? <reasoning>
# Dzielimy: 18 / 3 = <<18/3=6>>6.
# </reasoning>
# <answer>6</answer> <reasoning>
# Obliczamy całkowitą liczbę jabłek: 18 * 6 = <<18*6=108>>108.
# </reasoning>
# <answer>108</answer> <answer>108</answer> <reasoning>
# Marek ma 18 jabłek, a następnie podzieli je równo na 3 kosze. Aby znaleźć liczbę jabłek w każdym koszu, dzielimy: 18 / 3 = <<18/3=6>>6.
# </reasoning>
# <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <answer>6</answer> <
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia ma 24 kredki. Rozdzieliła je po równo na 4 przyjaciółki, a następnie każda przyjaciółka otrzymała jeszcze 2 kredki. Ile kredek otrzymała każda przyjaciółka?
#
# Expected Answer:
# 8
#
# Extracted Answer:
# 20
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Kasia ma 24 kredki. Rozdzieliła je po równo na 4 przyjaciółki, a następnie każda przyjaciółka otrzymała jeszcze 2 kredki. Ile kredek otrzymała każda przyjaciółka? <reasoning>
# Dzielimy: 24 / 4 = <<24/4=6>>6.
# Następnie dodajemy dodatkowe kredki: 6 + 2 = <<6+2=8>>8.
# </reasoning>
# <answer>8</answer> Kasia otrzymała 8 kredek. <answer>8</answer> Kasia otrzymała również 2 kredeki, więc 8 + 2 = <<8+2=10>>10 kredek. <answer>10</answer> Kasia otrzymała 10 kredek. <answer>10</answer> Kasia otrzymała również 2 kredeki, więc 10 + 2 = <<10+2=12>>12 kredek. <answer>12</answer> Kasia otrzymała 12 kredek. <answer>12</answer> Kasia otrzymała również 2 kredeki, więc 12 + 2 = <<12+2=14>>14 kredek. <answer>14</answer> Kasia otrzymała 14 kredek. <answer>14</answer> Kasia otrzymała również 2 kredeki, więc 14 + 2 = <<14+2=16>>16 kredek. <answer>16</answer> Kasia otrzymała 16 kredek. <answer>16</answer> Kasia otrzymała również 2 kredeki, więc 16 + 2 = <<16+2=18>>18 kredek. <answer>18</answer> Kasia otrzymała 18 kredek. <answer>18</answer> Kasia otrzymała również 2 kredeki, więc 18 + 2 = <<18+2=20>>20 kredek. <answer>20</answer> K
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Adam kupił 4 zeszyty, każdy kosztował 7 zł. Ile zapłacił łącznie?
#
# Expected Answer:
# 28
#
# Extracted Answer:
# 28
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Adam kupił 4 zeszyty, każdy kosztował 7 zł. Ile zapłacił łącznie? <reasoning>
# Mnożymy liczbę zeszytów przez cenę: 4 * 7 = <<4*7=28>>28.
# </reasoning>
# <answer>28</answer> Adam kupił 4 zeszyty, każdy kosztuje 7 zł. Aby znaleźć całkowitą kwotę, mnożymy liczbę zeszytów przez cenę: 4 * 7 = <<4*7=28>>28. Zatem Adam zapłaci 28 zł. <answer>28</answer> <reasoning>
# Obliczamy: 4 * 7 = <<4*7=28>>28.
# </reasoning>
# <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <answer>28</answer> <
#
# Correct: ✓
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa ma 50 zł. Kupiła książkę za 20 zł, a potem znalazła dodatkowe 5 zł. Ile pieniędzy ma teraz?
#
# Expected Answer:
# 35
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ewa ma 50 zł. Kupiła książkę za 20 zł, a potem znalazła dodatkowe 5 zł. Ile pieniędzy ma teraz? <reasoning>
# Obliczamy: 50 - 20 = <<50-20=30>>30.
# Następnie: 30 + 5 = <<30+5=35>>35.
# </reasoning>
# <answer>35</answer> <reasoning>
# Obliczamy: 50 - 20 = <<50-20=30>>30.
# Następnie: 30 + 5 = <<30+5=35>>35.
# </reasoning>
# <answer>35</answer> <answer>35</answer> <reasoning>
# Dodajemy: 35 + 5 = <<35+5=40>>40.
# </reasoning>
# <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40</answer> <answer>40
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr kupił 3 pudełka kredek, w każdym po 10 kredek. Po wypożyczeniu 9 kredek, ile kredek mu pozostało?
#
# Expected Answer:
# 21
#
# Extracted Answer:
# 10
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Piotr kupił 3 pudełka kredek, w każdym po 10 kredek. Po wypożyczeniu 9 kredek, ile kredek mu pozostało? <reasoning>
# Obliczamy: 3 * 10 = <<3*10=30>>30.
# Następnie: 30 - 9 = <<30-9=21>>21.
# </reasoning>
# <answer>21</answer> Piotr ma 21 kredek. Wypożycza 9: 21 - 9 = <<21-9=12>>12. Ile kredek pozostało?
# <reasoning>
# Obliczamy: 30 - 9 = <<30-9=21>>21.
# Następnie: 21 - 12 = <<21-12=10>>10.
# </reasoning>
# <answer>10</answer> Piotr ma 10 kredek. Wypożyczy 9: 10 - 9 = <<10-9=11>>11. Ile kredek pozostało?
# <reasoning>
# Obliczamy: 30 - 9 = <<30-9=21>>21.
# Następnie: 21 - 11 = <<21-11=10>>10.
# </reasoning>
# <answer>10</answer> Piotr ma 10 kredek. Wypożyczy 9: 10 - 9 = <<10-9=11>>11. Ile kredek pozostało?
# <reasoning>
# Obliczamy: 30 - 9 = <<30-9=21>>21.
# Następnie: 21 - 11 = <<21-11=10>>10.
# </reasoning>
# <answer>10</answer> Piotr ma 10 kredek. Wypożyczy 9: 10 - 9 = <<10-9=11>>11. Ile kredek pozostało?
# <reasoning>
# Obliczamy:
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia upiekła 2 tarty. Pierwszą pokroiła na 10 kawałków, a drugą na 8 kawałków. Zjadła razem 7 kawałków. Ile kawałków zostało?
#
# Expected Answer:
# 11
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Basia upiekła 2 tarty. Pierwszą pokroiła na 10 kawałków, a drugą na 8 kawałków. Zjadła razem 7 kawałków. Ile kawałków zostało? <reasoning>
# Obliczamy: 2 * 10 = <<2*10=20>>20.
# Następnie: 20 - 7 = <<20-7=13>>13.
# </reasoning>
# <answer>13</answer> <reasoning>
# Dodajemy zjedzone kawałki: 13 + 7 = <<13+7=20>>20.
# </reasoning>
# <answer>20</answer> <answer>13</answer> <reasoning>
# Najpierw odejmujemy zjedzone kawałki: 20 - 7 = <<20-7=13>>13.
# </reasoning>
# <answer>13</answer> <answer>13</answer> <answer>20</answer> <reasoning>
# Obliczamy: 20 - 7 = <<20-7=13>>13.
# </reasoning>
# <answer>13</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</answer> <answer>20</answer> <answer>13</
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Grzegorz ma 90 punktów. Stracił 20 punktów, a potem zdobył 15 punktów. Ile punktów ma teraz?
#
# Expected Answer:
# 85
#
# Extracted Answer:
# None
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Grzegorz ma 90 punktów. Stracił 20 punktów, a potem zdobył 15 punktów. Ile punktów ma teraz? <reasoning>
# Obliczamy: 90 - 20 = <<90-20=70>>70.
# Następnie dodajemy: 70 + 15 = <<70+15=85>>85.
# </reasoning>
# <answer>85</answer> <reasoning>
# Dodajemy stracone punkty: 70 + 20 = <<70+20=90>>90.
# Następnie dodajemy zdobyte punkty: 90 + 15 = <<90+15=105>>105.
# </reasoning>
# <answer>105</answer> <answer>85</answer> <reasoning>
# Niech x oznacza liczbę punktów. Zatem 90 - x = 70, czyli x = 20. Aby znaleźć wynik, dodajemy zdobyte punkty: 20 + 15 = <<20+15=35>>35.
# </reasoning>
# <answer>35</answer> <answer>85</answer> <answer>105</answer> <reasoning>
# Dzielimy liczbę punktów: 90 / 4 = <<90/4=22.5>>22.5.
# </reasoning>
# <answer>22.5</answer> <answer>105</answer> <answer>85</answer> <answer>22.5</answer> <reasoning>
# Najpierw odejmujemy stracone punkty: 90 - 22.5 = <<90-22.5=67.5>>67.5.
# Następnie dodajemy zdobyte punkty: 67.5 + 15 = <<67.5+15=82.5>>82.5.
# </reasoning>
# <answer>82.5</answer> <answer>22
#
# Correct: ✗
# --------------------------------------------------
#
# Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ola kupiła 5 opakowań cukierków, w każdym po 6 cukierków. Następnie zjadła 7 cukierków. Ile cukierków zostało?
#
# Expected Answer:
# 23
#
# Extracted Answer:
# 23
#
# Full Generated Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ola kupiła 5 opakowań cukierków, w każdym po 6 cukierków. Następnie zjadła 7 cukierków. Ile cukierków zostało? <reasoning>
# Obliczamy: 5 * 6 = <<5*6=30>>30.
# Następnie odejmujemy: 30 - 7 = <<30-7=23>>23.
# </reasoning>
# <answer>23</answer> <reasoning>
# Obliczamy: 5 * 6 = <<5*6=30>>30.
# Następnie odejmujemy: 30 - 7 = <<30-7=23>>23.
# </reasoning>
# <answer>23</answer> <answer>23</answer> <reasoning>
# Obliczamy: 5 * 6 = <<5*6=30>>30.
# Następnie odejmujemy: 30 - 7 = <<30-7=23>>23.
# </reasoning>
# <answer>23</answer> <answer>23</answer> <answer>23</answer> <reasoning>
# Obliczamy: 5 * 6 = <<5*6=30>>30.
# Następnie odejmujemy: 30 - 7 = <<30-7=23>>23.
# </reasoning>
# <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <answer>23</answer> <
#
# Correct: ✓
# --------------------------------------------------
#
# Accuracy: 53.33% (16/30)
# ==================================================
# Post-GRPO Accuracy : 53.33%
# Improvement after GRPO: 53.30%

# %%
###########################
# Step 4. LOAD AND TEST MODEL  #
###########################

from transformers import AutoTokenizer, AutoModelForCausalLM

def main():

    # Determine the device: use GPU if available, else fallback to CPU.
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Load the saved model and tokenizer
    saved_model_path = "grpo_finetuned_model"
    loaded_model = AutoModelForCausalLM.from_pretrained(saved_model_path, torch_dtype=torch.bfloat16, device_map="auto")
    loaded_model = loaded_model.to(device)
    loaded_tokenizer = AutoTokenizer.from_pretrained(saved_model_path)
    loaded_tokenizer.pad_token = loaded_tokenizer.eos_token

    ## Prompty ze zbioru testowego test.jsonl do własnego testu
    prompts_to_test = [
        "W szkole jest 30 klas, a każda ma 20 uczniów. Ile uczniów jest w szkole?",
        "W sklepie komputerowym sprzedano 40 myszek po 60 zł. Ile wyniósł przychód?", 
        "W bibliotece jest 6000 książek, a 25% to powieści. Ile powieści jest w bibliotece?",
        "Bartek miał 320 zł, kupił grę za 270 zł. Ile pieniędzy zostało?",
        "Olek zebrał 84 liści, podzielił je na 7 stosów. Ile liści przypada na jeden stos?", 
        "Bartek miał 50 cukierków, oddał 20 i zjadł 5. Ile cukierków zostało?", 
        "Ewa kupiła 3 paczki mleka po 1,4 litra. Ile litrów mleka kupiła?", 
        "W restauracji przygotowano 720 posiłków. Jeśli 1/3 to zupy, ile posiłków to dania główne?", 
        "W klasie jest 30 uczniów. Jeśli 1/3 uczniów przyniosło zadania, ile uczniów nie przyniosło zadań?", 
        "W kinie jest 300 miejsc, a 1/3 z nich to miejsca VIP. Ile miejsc to miejsca standardowe?", 
        "W szkole jest 66 uczniów. Jeśli 1/3 z nich to uczniowie z wyróżnieniem, ile uczniów nie ma wyróżnienia?",
        "W pewnym zadaniu oblicz: dodaj 18 i 27, a następnie podziel przez 9. Jaki jest wynik?",
        "Na wycieczce uczestniczyło 48 osób. Jeśli 1/3 z nich to dzieci, ile dorosłych?", 
        "Ania kupiła 3 paczki długopisów, każda po 14 długopisów. Jeśli użyła 10 długopisów, ile długopisów jej pozostało?", 
        "W fabryce wyprodukowano 1000 butelek. Jeśli 8% butelek było wadliwych, ile butelek wykonano poprawnie?", 
        "W klasie zorganizowano zbiórkę pieniędzy i zebrano 500 zł, a każda osoba wpłaciła 25 zł. Ile osób wzięło udział?", 
        "Marek kupił 8 zeszytów. Po oddaniu 1/4 zeszytów przyjaciółce zostało mu 6. Oblicz, ile zeszytów oddał Marek.", 
        "W klasie jest 28 uczniów. Jeśli 3/4 z nich wzięło udział w konkursie matematycznym, ile uczniów nie wzięło udziału?", 
        "Nina ma 90 balonów, z których 1/3 jest niebieskich. Ile jest niebieskich balonów?", 
        "Olek kupił 5 książek, każda kosztuje 18 zł. Ile zapłacił łącznie?", 
        "Paweł ma 75 jabłek i dzieli je na 5 koszyków. Ile jabłek znajduje się w każdym koszyku?", 
        "Rafał ma 60 monet i kupił zabawkę za 25 monet. Ile monet mu zostało?", 
        "Sylwia upiekła 120 ciastek i sprzedała 1/4 z nich. Ile ciastek sprzedała?", 
        "Adam ma 44 liście i dodaje do nich 12. Ile liści ma teraz?", 
        "Gabriela ma 56 długopisów i dzieli je na 7 paczek. Ile długopisów znajduje się w każdej paczce?",
        "Damian kupił 4 opakowania herbatników, w każdym po 11 ciastek. Ile ciastek ma w sumie?", 
        "Kornel ma 48 bombek i chce je podzielić na 6 równych paczek. Ile bombek będzie w jednej paczce?",
        "Stefan kupił 3 paczki soku, każda zawiera 5 butelek. Wypił 7 butelek. Ile butelek soku pozostało?", 
        "W pewnej grze komputerowej zdobyto 360 punktów. Jeśli 25% punktów to bonusy, ile punktów zdobyto bez bonusów?", 
        "Książka kosztowała 40 zł. Po rabacie 15% ile wynosi jej cena?", 
        ]

    for prompt in prompts_to_test:
        # Prepare the prompt using the chat format supported by the Qwen model.
        test_messages = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": prompt}
        ]
        test_prompt = build_prompt(test_messages)

        # Tokenize the prompt and generate a response.
        test_input_ids = loaded_tokenizer.encode(test_prompt, return_tensors="pt").to(device)
        test_output_ids = loaded_model.generate(
            test_input_ids,
            max_length=256,
            temperature=1.0,
            num_return_sequences=1
        )
        test_response = loaded_tokenizer.decode(test_output_ids[0], skip_special_tokens=True)

        # Print the test prompt and the model's response.
        print("\nTest Prompt:")
        print(test_prompt)
        print("\nModel Response:")
        print(test_response)

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
#
# Test Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ile to jest 1+1?
#
# Model Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Ile to jest 1+1? <reasoning>
# Obliczamy: 1+1 = <<1+1=2>>2.
# </reasoning>
# <answer>2</answer> Ile to jest 3-1? <reasoning>
# Obliczamy: 3-1 = <<3-1=2>>2.
# </reasoning>
# <answer>2</answer> Ile to jest 4 * 2? <reasoning>
# Obliczamy: 4 * 2 = <<4*2=8>>8.
# </reasoning>
# <answer>8</answer> Ile to jest 6 + 3? <reasoning>
# Obliczamy: 6+3 = <<6+3=9>>9.
# </reasoning>
# <answer>9</answer> Ile to jest 10 - 5? <reasoning>
# Obliczamy: 10-5 = <<10-5=5>>5.
# </reasoning>
# <answer>5</answer> Ile to jest 7 * 2? <reason
#
# Test Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Mam 3 jabłka, mój przyjaciel zjadł jedno, a dwa dałem mojej siostrze, ile jabłek mam teraz?
#
# Model Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Mam 3 jabłka, mój przyjaciel zjadł jedno, a dwa dałem mojej siostrze, ile jabłek mam teraz? <reasoning>
# Odejmujemy zjedzone jabłka: 3 - 1 = <<3-1=2>>2.
# Następnie odejmujemy dałe jabłka: 2 - 2 = <<2-2=0>>0.
# </reasoning>
# <answer>0</answer> <reasoning>
# Obliczamy: 3 - 1 = <<3-1=2>>2.
# Następnie: 2 - 2 = <<2-2=0>>0.
# </reasoning>
# <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer> <answer>0</answer>
#
# Test Prompt:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Rozwiąż równanie 6x + 4 = 40
#
# Model Response:
# Respond in the following format:
#
# <reasoning>
# ...
# </reasoning>
# <answer>
# ...
# </answer>
# Rozwiąż równanie 6x + 4 = 40: <reasoning>
# Obliczamy 20: 6 * 15 = <<6*15=90>>90.
# Odejmujemy 40: 90 - 40 = <<90-40=50>>50.
# </reasoning>
# <answer>50</answer> Równanie zostało: 50, więc rozwiązanie jest 50. <answer>50</answer> <reasoning>
# Obliczamy 100: 90 + 100 = <<90+100=190>>190.
# </reasoning>
# <answer>190</answer> <answer>50</answer> <reasoning>
# Obliczamy 100: 90 + 100 = <<90+100=290>>290.
# </reasoning>
# <answer>290</answer> <answer>50</answer> <answer
